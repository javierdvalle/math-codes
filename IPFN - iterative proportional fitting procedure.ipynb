# %% [markdown]
# https://u.demog.berkeley.edu/~eddieh/IPFDescription/AKDOLWDIPFTWOD.pdf
#
# https://pypi.org/project/ipfn/
#
# https://en.wikipedia.org/wiki/Iterative_proportional_fitting

# %% [markdown]
# ![image.png](attachment:e5cd1fdf-bf24-42d6-8469-f4e3eb1433f4.png)
