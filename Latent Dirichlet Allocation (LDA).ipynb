# %% [markdown]
# ## LATENT DIRICHLET ALLOCATION
#
# https://medium.com/@lettier/how-does-lda-work-ill-explain-using-emoji-108abf40fa7d
#
# https://www.youtube.com/watch?v=DWJYZq_fQ2A

# %%
import random
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

topic1 = {
    'id': 'sports', 
    'words': ['football', 'basketball', 'gol', 'play', 'match', 'space'],
    'weights': [4, 1, 1, 1, 1, 2]
}
topic2 = {
    'id': 'politics', 
    'words': ['president', 'interview', 'twitter', 'television', 'debate', 'space'],
    'weights': [2, 1, 4, 1, 1, 1]
}
topic3 = {
    'id': 'science', 
    'words': ['science', 'molecula', 'debate', 'space'],
    'weights': [1, 1, 1, 1]
}

topics = [topic1, topic2, topic3]


# topic1 = {
#     'id': 'sports', 
#     'words': ['football', 'basketball', 'match'],
#     'weights': [1,1,1]
# }
# topic2 = {
#     'id': 'politics', 
#     'words': ['president', 'interview', 'twitter'],
#     'weights': [1, 1, 1]
# }
# topic3 = {
#     'id': 'science', 
#     'words': ['science', 'molecula', 'space'],
#     'weights': [1, 1, 1]
# }

topics = [topic1, topic2, topic3]


# topic1 = {
#     'id': 'dogs', 
#     'words': ['guau', 'guau2'],
#     'weights': [1, 1]
# }
# topic2 = {
#     'id': 'cats', 
#     'words': ['miaw', 'miaw2'],
#     'weights': [1, 1]
# }

# topics = [topic1, topic2]

# %% [markdown]
# ## Generar documentos

# %%
def generate_documents(topics, num_docs=100, topics_per_doc=2, words_per_doc=1000):
    documents = []
    for i in range(num_docs):
        # first select several topics
        doc_topics = random.sample(topics, topics_per_doc)

        # asign a weight to each topic of the document
        r = [random.random() for _ in range(0, topics_per_doc)]
        s = sum(r)
        doc_topics_weights = [ j/s for j in r ]
        
        # now sample the topics to generate the document. 
        # NOTE: this is an inefficient version for teaching purposes
        doc_words = [] 
        for _ in range(words_per_doc):
            topic = random.choices(doc_topics, doc_topics_weights)[0]  # select one topic
            doc_words = doc_words + random.choices(topic['words'], topic['weights'], k=1)  # choose one word
        
        documents.append({'id': i, 'words': doc_words, 'topics_weights': [(t[0]['id'], t[1]) for t in zip(doc_topics, doc_topics_weights)]})
        
        words_idx = list(set([word for doc in documents for word in doc['words']]))
        docs_idx = [doc['id'] for doc in documents]
        topics_idx = [t['id'] for t in topics]
    return documents, docs_idx, words_idx, topics_idx


docs, docs_idx, words_idx, topics_idx = generate_documents(topics, num_docs=100, topics_per_doc=2, words_per_doc=100)
docs
# Out:
# [{'id': 0,
#   'words': ['twitter',
#    'twitter',
#    'interview',
#    'twitter',
#    'football',
#    'debate',
#    'television',
#    'twitter',
#    'play',
#    'football',
#    'television',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'space',
#    'space',
#    'match',
#    'twitter',
#    'football',
#    'twitter',
#    'space',
#    'television',
#    'president',
#    'president',
#    'gol',
#    'space',
#    'twitter',
#    'president',
#    'television',
#    'twitter',
#    'twitter',
#    'football',
#    'twitter',
#    'space',
#    'football',
#    'president',
#    'television',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'football',
#    'football',
#    'interview',
#    'president',
#    'interview',
#    'football',
#    'debate',
#    'president',
#    'president',
#    'play',
#    'space',
#    'match',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'match',
#    'space',
#    'debate',
#    'debate',
#    'twitter',
#    'space',
#    'president',
#    'match',
#    'space',
#    'president',
#    'twitter',
#    'space',
#    'football',
#    'twitter',
#    'gol',
#    'television',
#    'twitter',
#    'space',
#    'play',
#    'gol',
#    'match',
#    'football',
#    'space',
#    'basketball',
#    'gol',
#    'television',
#    'president',
#    'president',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'gol',
#    'match',
#    'match',
#    'space',
#    'debate',
#    'space',
#    'twitter',
#    'football'],
#   'topics_weights': [('sports', 0.41634218576901727),
#    ('politics', 0.5836578142309828)]},
#  {'id': 1,
#   'words': ['molecula',
#    'twitter',
#    'science',
#    'president',
#    'molecula',
#    'space',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'television',
#    'science',
#    'science',
#    'debate',
#    'debate',
#    'debate',
#    'television',
#    'science',
#    'president',
#    'president',
#    'television',
#    'space',
#    'space',
#    'molecula',
#    'twitter',
#    'president',
#    'debate',
#    'molecula',
#    'president',
#    'science',
#    'molecula',
#    'science',
#    'twitter',
#    'science',
#    'president',
#    'space',
#    'molecula',
#    'president',
#    'space',
#    'space',
#    'space',
#    'debate',
#    'twitter',
#    'science',
#    'debate',
#    'twitter',
#    'television',
#    'television',
#    'twitter',
#    'president',
#    'space',
#    'television',
#    'space',
#    'space',
#    'space',
#    'science',
#    'television',
#    'debate',
#    'twitter',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'debate',
#    'twitter',
#    'debate',
#    'molecula',
#    'space',
#    'interview',
#    'twitter',
#    'debate',
#    'television',
#    'space',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'debate',
#    'twitter',
#    'president',
#    'debate',
#    'television',
#    'president',
#    'twitter',
#    'space',
#    'debate',
#    'twitter',
#    'molecula',
#    'twitter',
#    'debate',
#    'science',
#    'president',
#    'debate',
#    'molecula',
#    'space',
#    'molecula',
#    'twitter',
#    'debate'],
#   'topics_weights': [('science', 0.45330781902902145),
#    ('politics', 0.5466921809709785)]},
#  {'id': 2,
#   'words': ['twitter',
#    'molecula',
#    'president',
#    'twitter',
#    'molecula',
#    'television',
#    'molecula',
#    'television',
#    'interview',
#    'debate',
#    'debate',
#    'molecula',
#    'molecula',
#    'twitter',
#    'science',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'debate',
#    'twitter',
#    'twitter',
#    'president',
#    'science',
#    'space',
#    'science',
#    'president',
#    'science',
#    'president',
#    'space',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'president',
#    'debate',
#    'space',
#    'twitter',
#    'space',
#    'space',
#    'space',
#    'twitter',
#    'molecula',
#    'science',
#    'twitter',
#    'molecula',
#    'space',
#    'twitter',
#    'science',
#    'space',
#    'interview',
#    'twitter',
#    'debate',
#    'president',
#    'debate',
#    'president',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'twitter',
#    'president',
#    'television',
#    'space',
#    'debate',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'science',
#    'science',
#    'debate',
#    'twitter',
#    'molecula',
#    'television',
#    'television',
#    'interview',
#    'molecula',
#    'science',
#    'twitter',
#    'president',
#    'space',
#    'television',
#    'interview',
#    'twitter',
#    'television',
#    'twitter',
#    'molecula',
#    'science',
#    'twitter',
#    'space',
#    'twitter',
#    'president',
#    'debate',
#    'twitter'],
#   'topics_weights': [('politics', 0.5075126087863304),
#    ('science', 0.49248739121366963)]},
#  {'id': 3,
#   'words': ['president',
#    'twitter',
#    'television',
#    'football',
#    'space',
#    'space',
#    'twitter',
#    'football',
#    'football',
#    'football',
#    'basketball',
#    'basketball',
#    'twitter',
#    'football',
#    'basketball',
#    'president',
#    'twitter',
#    'basketball',
#    'football',
#    'space',
#    'president',
#    'play',
#    'gol',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'space',
#    'gol',
#    'football',
#    'twitter',
#    'basketball',
#    'play',
#    'football',
#    'football',
#    'interview',
#    'space',
#    'space',
#    'football',
#    'play',
#    'match',
#    'space',
#    'football',
#    'football',
#    'space',
#    'play',
#    'space',
#    'twitter',
#    'football',
#    'president',
#    'debate',
#    'space',
#    'space',
#    'football',
#    'president',
#    'football',
#    'football',
#    'twitter',
#    'football',
#    'space',
#    'debate',
#    'twitter',
#    'football',
#    'president',
#    'space',
#    'twitter',
#    'interview',
#    'football',
#    'debate',
#    'twitter',
#    'play',
#    'space',
#    'space',
#    'football',
#    'debate',
#    'space',
#    'twitter',
#    'play',
#    'twitter',
#    'television',
#    'football',
#    'debate',
#    'football',
#    'basketball',
#    'play',
#    'television',
#    'basketball',
#    'gol',
#    'match',
#    'football',
#    'basketball',
#    'gol',
#    'football',
#    'space',
#    'space',
#    'president',
#    'twitter',
#    'football',
#    'space',
#    'television'],
#   'topics_weights': [('politics', 0.3664851835429217),
#    ('sports', 0.6335148164570782)]},
#  {'id': 4,
#   'words': ['science',
#    'space',
#    'molecula',
#    'twitter',
#    'debate',
#    'debate',
#    'molecula',
#    'twitter',
#    'space',
#    'molecula',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'molecula',
#    'space',
#    'twitter',
#    'television',
#    'science',
#    'molecula',
#    'interview',
#    'science',
#    'debate',
#    'molecula',
#    'twitter',
#    'twitter',
#    'twitter',
#    'molecula',
#    'science',
#    'molecula',
#    'television',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'space',
#    'president',
#    'debate',
#    'president',
#    'molecula',
#    'space',
#    'twitter',
#    'twitter',
#    'debate',
#    'molecula',
#    'debate',
#    'debate',
#    'debate',
#    'science',
#    'president',
#    'president',
#    'molecula',
#    'television',
#    'space',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'president',
#    'science',
#    'debate',
#    'twitter',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'president',
#    'debate',
#    'science',
#    'president',
#    'interview',
#    'president',
#    'twitter',
#    'debate',
#    'debate',
#    'science',
#    'debate',
#    'debate',
#    'science',
#    'twitter',
#    'television',
#    'science',
#    'twitter',
#    'debate',
#    'debate',
#    'twitter',
#    'debate',
#    'science',
#    'science',
#    'science',
#    'president',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'science',
#    'twitter',
#    'molecula'],
#   'topics_weights': [('science', 0.5059400711565296),
#    ('politics', 0.49405992884347044)]},
#  {'id': 5,
#   'words': ['twitter',
#    'space',
#    'football',
#    'play',
#    'match',
#    'space',
#    'debate',
#    'play',
#    'match',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'basketball',
#    'football',
#    'interview',
#    'twitter',
#    'twitter',
#    'debate',
#    'president',
#    'football',
#    'interview',
#    'president',
#    'twitter',
#    'football',
#    'twitter',
#    'twitter',
#    'president',
#    'president',
#    'football',
#    'basketball',
#    'basketball',
#    'twitter',
#    'debate',
#    'television',
#    'television',
#    'space',
#    'gol',
#    'president',
#    'football',
#    'president',
#    'football',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'basketball',
#    'twitter',
#    'space',
#    'football',
#    'match',
#    'twitter',
#    'space',
#    'football',
#    'play',
#    'twitter',
#    'space',
#    'president',
#    'interview',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'football',
#    'twitter',
#    'space',
#    'basketball',
#    'television',
#    'television',
#    'space',
#    'space',
#    'football',
#    'television',
#    'president',
#    'football',
#    'president',
#    'football',
#    'twitter',
#    'space',
#    'play',
#    'basketball',
#    'match',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'football',
#    'debate',
#    'football',
#    'twitter',
#    'twitter'],
#   'topics_weights': [('sports', 0.411816307767475),
#    ('politics', 0.588183692232525)]},
#  {'id': 6,
#   'words': ['twitter',
#    'gol',
#    'space',
#    'president',
#    'space',
#    'television',
#    'president',
#    'gol',
#    'debate',
#    'football',
#    'interview',
#    'play',
#    'debate',
#    'football',
#    'television',
#    'football',
#    'space',
#    'basketball',
#    'football',
#    'interview',
#    'match',
#    'space',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'football',
#    'interview',
#    'debate',
#    'space',
#    'television',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'twitter',
#    'football',
#    'match',
#    'twitter',
#    'space',
#    'debate',
#    'twitter',
#    'match',
#    'space',
#    'basketball',
#    'football',
#    'twitter',
#    'gol',
#    'twitter',
#    'twitter',
#    'television',
#    'gol',
#    'play',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'president',
#    'football',
#    'play',
#    'twitter',
#    'gol',
#    'twitter',
#    'twitter',
#    'television',
#    'football',
#    'match',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'basketball',
#    'debate',
#    'play',
#    'twitter',
#    'play',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'gol',
#    'president',
#    'twitter',
#    'president',
#    'interview',
#    'twitter',
#    'football',
#    'debate',
#    'basketball',
#    'match',
#    'twitter',
#    'twitter',
#    'space',
#    'space'],
#   'topics_weights': [('politics', 0.5257294683391286),
#    ('sports', 0.47427053166087146)]},
#  {'id': 7,
#   'words': ['play',
#    'gol',
#    'space',
#    'science',
#    'football',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'gol',
#    'debate',
#    'football',
#    'molecula',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'basketball',
#    'play',
#    'science',
#    'football',
#    'molecula',
#    'space',
#    'molecula',
#    'debate',
#    'football',
#    'basketball',
#    'molecula',
#    'match',
#    'space',
#    'molecula',
#    'space',
#    'football',
#    'play',
#    'match',
#    'science',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'play',
#    'basketball',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'science',
#    'football',
#    'molecula',
#    'football',
#    'debate',
#    'match',
#    'football',
#    'space',
#    'play',
#    'space',
#    'debate',
#    'gol',
#    'space',
#    'space',
#    'space',
#    'basketball',
#    'science',
#    'space',
#    'molecula',
#    'play',
#    'football',
#    'space',
#    'space',
#    'science',
#    'basketball',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'space',
#    'molecula',
#    'match',
#    'basketball',
#    'debate',
#    'football',
#    'space',
#    'football',
#    'football',
#    'gol',
#    'football',
#    'science',
#    'molecula',
#    'space',
#    'football'],
#   'topics_weights': [('science', 0.4854908030335585),
#    ('sports', 0.5145091969664415)]},
#  {'id': 8,
#   'words': ['interview',
#    'science',
#    'science',
#    'science',
#    'interview',
#    'twitter',
#    'molecula',
#    'molecula',
#    'president',
#    'interview',
#    'molecula',
#    'science',
#    'space',
#    'twitter',
#    'twitter',
#    'molecula',
#    'twitter',
#    'debate',
#    'debate',
#    'president',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'interview',
#    'molecula',
#    'president',
#    'president',
#    'twitter',
#    'twitter',
#    'debate',
#    'space',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'molecula',
#    'molecula',
#    'president',
#    'twitter',
#    'president',
#    'television',
#    'twitter',
#    'interview',
#    'debate',
#    'science',
#    'twitter',
#    'space',
#    'twitter',
#    'debate',
#    'space',
#    'president',
#    'television',
#    'debate',
#    'debate',
#    'television',
#    'space',
#    'interview',
#    'molecula',
#    'molecula',
#    'debate',
#    'molecula',
#    'television',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'television',
#    'twitter',
#    'space',
#    'molecula',
#    'space',
#    'twitter',
#    'debate',
#    'science',
#    'molecula',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'twitter',
#    'debate',
#    'space',
#    'twitter',
#    'space',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'molecula',
#    'science',
#    'space',
#    'space',
#    'molecula',
#    'debate',
#    'debate',
#    'science',
#    'debate',
#    'president'],
#   'topics_weights': [('science', 0.47130562499188616),
#    ('politics', 0.5286943750081139)]},
#  {'id': 9,
#   'words': ['space',
#    'football',
#    'twitter',
#    'twitter',
#    'play',
#    'football',
#    'twitter',
#    'space',
#    'debate',
#    'space',
#    'twitter',
#    'gol',
#    'match',
#    'television',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'interview',
#    'twitter',
#    'interview',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'space',
#    'president',
#    'football',
#    'twitter',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'interview',
#    'debate',
#    'president',
#    'president',
#    'television',
#    'twitter',
#    'television',
#    'interview',
#    'football',
#    'television',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'football',
#    'twitter',
#    'play',
#    'television',
#    'twitter',
#    'debate',
#    'twitter',
#    'television',
#    'twitter',
#    'interview',
#    'match',
#    'space',
#    'twitter',
#    'interview',
#    'twitter',
#    'twitter',
#    'space',
#    'space',
#    'football',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'interview',
#    'debate',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'interview',
#    'president',
#    'twitter',
#    'debate',
#    'president',
#    'debate',
#    'president',
#    'debate'],
#   'topics_weights': [('politics', 0.8353794994367448),
#    ('sports', 0.16462050056325517)]},
#  {'id': 10,
#   'words': ['space',
#    'football',
#    'debate',
#    'football',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'debate',
#    'play',
#    'space',
#    'football',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'space',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'science',
#    'molecula',
#    'science',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'debate',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'science',
#    'space',
#    'match',
#    'space',
#    'space',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'science',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'space',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'play',
#    'molecula',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'molecula',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'science'],
#   'topics_weights': [('science', 0.925128646593329),
#    ('sports', 0.07487135340667096)]},
#  {'id': 11,
#   'words': ['president',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'basketball',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'football',
#    'twitter',
#    'interview',
#    'interview',
#    'debate',
#    'twitter',
#    'interview',
#    'gol',
#    'twitter',
#    'interview',
#    'twitter',
#    'twitter',
#    'president',
#    'interview',
#    'space',
#    'debate',
#    'president',
#    'twitter',
#    'television',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'match',
#    'president',
#    'president',
#    'space',
#    'debate',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'interview',
#    'twitter',
#    'twitter',
#    'space',
#    'football',
#    'interview',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'football',
#    'interview',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'twitter',
#    'space',
#    'football',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'president',
#    'space',
#    'twitter',
#    'space',
#    'football',
#    'twitter',
#    'basketball',
#    'president',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'gol',
#    'twitter',
#    'twitter',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'interview',
#    'debate',
#    'president',
#    'debate'],
#   'topics_weights': [('politics', 0.838716240008223),
#    ('sports', 0.16128375999177702)]},
#  {'id': 12,
#   'words': ['debate',
#    'play',
#    'football',
#    'football',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'gol',
#    'basketball',
#    'football',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'space',
#    'football',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'football',
#    'basketball',
#    'football',
#    'debate',
#    'football',
#    'molecula',
#    'play',
#    'football',
#    'football',
#    'debate',
#    'molecula',
#    'football',
#    'space',
#    'science',
#    'space',
#    'basketball',
#    'football',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'molecula',
#    'football',
#    'debate',
#    'molecula',
#    'football',
#    'football',
#    'play',
#    'gol',
#    'molecula',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'gol',
#    'football',
#    'football',
#    'molecula',
#    'space',
#    'match',
#    'gol',
#    'football',
#    'science',
#    'science',
#    'space',
#    'play',
#    'science',
#    'match',
#    'match',
#    'debate',
#    'science',
#    'space',
#    'football',
#    'match',
#    'debate',
#    'football',
#    'space',
#    'molecula',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'debate',
#    'play',
#    'football',
#    'space',
#    'basketball',
#    'football',
#    'basketball',
#    'debate'],
#   'topics_weights': [('science', 0.44056835934874133),
#    ('sports', 0.5594316406512587)]},
#  {'id': 13,
#   'words': ['football',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'twitter',
#    'gol',
#    'play',
#    'twitter',
#    'space',
#    'match',
#    'space',
#    'twitter',
#    'match',
#    'interview',
#    'twitter',
#    'debate',
#    'football',
#    'match',
#    'football',
#    'match',
#    'twitter',
#    'match',
#    'space',
#    'football',
#    'football',
#    'space',
#    'match',
#    'president',
#    'space',
#    'basketball',
#    'television',
#    'space',
#    'football',
#    'football',
#    'football',
#    'space',
#    'basketball',
#    'debate',
#    'football',
#    'twitter',
#    'gol',
#    'space',
#    'president',
#    'twitter',
#    'gol',
#    'football',
#    'football',
#    'match',
#    'football',
#    'football',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'play',
#    'space',
#    'twitter',
#    'twitter',
#    'play',
#    'gol',
#    'football',
#    'match',
#    'match',
#    'match',
#    'football',
#    'twitter',
#    'football',
#    'twitter',
#    'match',
#    'basketball',
#    'twitter',
#    'football',
#    'space',
#    'play',
#    'play',
#    'space',
#    'president',
#    'football',
#    'football',
#    'football',
#    'twitter',
#    'gol',
#    'space',
#    'football',
#    'play',
#    'play',
#    'space',
#    'twitter',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'football',
#    'basketball'],
#   'topics_weights': [('sports', 0.7403295076147447),
#    ('politics', 0.25967049238525525)]},
#  {'id': 14,
#   'words': ['president',
#    'gol',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'interview',
#    'football',
#    'twitter',
#    'football',
#    'president',
#    'twitter',
#    'football',
#    'football',
#    'president',
#    'president',
#    'gol',
#    'interview',
#    'president',
#    'president',
#    'twitter',
#    'president',
#    'space',
#    'basketball',
#    'match',
#    'debate',
#    'president',
#    'interview',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'basketball',
#    'gol',
#    'twitter',
#    'debate',
#    'gol',
#    'debate',
#    'president',
#    'television',
#    'debate',
#    'twitter',
#    'interview',
#    'football',
#    'president',
#    'football',
#    'debate',
#    'play',
#    'twitter',
#    'space',
#    'television',
#    'play',
#    'president',
#    'play',
#    'space',
#    'president',
#    'president',
#    'twitter',
#    'gol',
#    'twitter',
#    'twitter',
#    'football',
#    'space',
#    'space',
#    'gol',
#    'interview',
#    'twitter',
#    'match',
#    'twitter',
#    'play',
#    'play',
#    'basketball',
#    'football',
#    'space',
#    'play',
#    'twitter',
#    'space',
#    'match',
#    'president',
#    'gol',
#    'match',
#    'match',
#    'debate',
#    'space',
#    'debate',
#    'interview',
#    'football',
#    'president',
#    'space',
#    'football',
#    'debate',
#    'space',
#    'space',
#    'gol',
#    'gol',
#    'twitter',
#    'play'],
#   'topics_weights': [('sports', 0.5681564180862291),
#    ('politics', 0.43184358191377087)]},
#  {'id': 15,
#   'words': ['space',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'space',
#    'molecula',
#    'space',
#    'twitter',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'molecula',
#    'space',
#    'space',
#    'debate',
#    'debate',
#    'molecula',
#    'molecula',
#    'space',
#    'science',
#    'debate',
#    'debate',
#    'debate',
#    'molecula',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'molecula',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'molecula',
#    'debate',
#    'science',
#    'science',
#    'debate',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'science',
#    'science',
#    'science',
#    'science',
#    'debate',
#    'science',
#    'science',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'science',
#    'science',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'space',
#    'molecula',
#    'debate',
#    'science',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'debate',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'twitter',
#    'molecula'],
#   'topics_weights': [('science', 0.9604114777186262),
#    ('politics', 0.03958852228137383)]},
#  {'id': 16,
#   'words': ['space',
#    'debate',
#    'space',
#    'debate',
#    'play',
#    'debate',
#    'debate',
#    'gol',
#    'molecula',
#    'space',
#    'football',
#    'gol',
#    'molecula',
#    'match',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'debate',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'football',
#    'play',
#    'space',
#    'play',
#    'space',
#    'gol',
#    'football',
#    'science',
#    'debate',
#    'match',
#    'football',
#    'debate',
#    'gol',
#    'space',
#    'gol',
#    'football',
#    'football',
#    'debate',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'space',
#    'match',
#    'molecula',
#    'molecula',
#    'football',
#    'science',
#    'space',
#    'space',
#    'molecula',
#    'molecula',
#    'match',
#    'debate',
#    'science',
#    'basketball',
#    'football',
#    'gol',
#    'play',
#    'football',
#    'space',
#    'science',
#    'space',
#    'football',
#    'molecula',
#    'molecula',
#    'molecula',
#    'gol',
#    'match',
#    'space',
#    'science',
#    'play',
#    'football',
#    'science',
#    'gol',
#    'space',
#    'football',
#    'match',
#    'football',
#    'space',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'space'],
#   'topics_weights': [('sports', 0.49320377150966677),
#    ('science', 0.5067962284903332)]},
#  {'id': 17,
#   'words': ['twitter',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'twitter',
#    'science',
#    'twitter',
#    'debate',
#    'science',
#    'space',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'molecula',
#    'twitter',
#    'twitter',
#    'science',
#    'molecula',
#    'debate',
#    'twitter',
#    'space',
#    'debate',
#    'television',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'twitter',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'president',
#    'space',
#    'twitter',
#    'president',
#    'molecula',
#    'television',
#    'debate',
#    'science',
#    'twitter',
#    'space',
#    'debate',
#    'science',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'science',
#    'molecula',
#    'debate',
#    'science',
#    'president',
#    'twitter',
#    'twitter',
#    'science',
#    'president',
#    'twitter',
#    'space',
#    'president',
#    'science',
#    'molecula',
#    'science',
#    'twitter',
#    'president',
#    'space',
#    'television',
#    'science',
#    'molecula',
#    'president',
#    'twitter',
#    'molecula',
#    'science',
#    'television',
#    'twitter',
#    'molecula',
#    'debate',
#    'debate',
#    'twitter',
#    'space',
#    'science',
#    'twitter',
#    'debate',
#    'twitter',
#    'space',
#    'science',
#    'debate',
#    'twitter',
#    'molecula',
#    'interview',
#    'debate',
#    'president',
#    'twitter',
#    'science'],
#   'topics_weights': [('politics', 0.6104548745806603),
#    ('science', 0.3895451254193397)]},
#  {'id': 18,
#   'words': ['basketball',
#    'gol',
#    'molecula',
#    'molecula',
#    'match',
#    'basketball',
#    'football',
#    'space',
#    'football',
#    'molecula',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'football',
#    'space',
#    'play',
#    'match',
#    'gol',
#    'basketball',
#    'space',
#    'football',
#    'match',
#    'molecula',
#    'basketball',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'football',
#    'space',
#    'space',
#    'space',
#    'space',
#    'football',
#    'debate',
#    'play',
#    'gol',
#    'football',
#    'basketball',
#    'molecula',
#    'football',
#    'basketball',
#    'match',
#    'football',
#    'basketball',
#    'match',
#    'football',
#    'gol',
#    'match',
#    'gol',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'gol',
#    'gol',
#    'football',
#    'football',
#    'match',
#    'space',
#    'space',
#    'match',
#    'gol',
#    'gol',
#    'space',
#    'debate',
#    'molecula',
#    'football',
#    'football',
#    'football',
#    'football',
#    'play',
#    'football',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'space',
#    'space',
#    'space',
#    'match',
#    'basketball',
#    'football',
#    'science',
#    'football',
#    'space',
#    'football',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'football',
#    'football',
#    'molecula',
#    'gol',
#    'football',
#    'space'],
#   'topics_weights': [('sports', 0.8831644476730502),
#    ('science', 0.11683555232694975)]},
#  {'id': 19,
#   'words': ['football',
#    'molecula',
#    'debate',
#    'science',
#    'space',
#    'football',
#    'football',
#    'molecula',
#    'science',
#    'science',
#    'science',
#    'football',
#    'molecula',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'science',
#    'space',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'debate',
#    'science',
#    'debate',
#    'science',
#    'play',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'science',
#    'science',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'space',
#    'play',
#    'molecula',
#    'molecula',
#    'space',
#    'molecula',
#    'debate',
#    'debate',
#    'debate',
#    'match',
#    'space',
#    'space',
#    'space',
#    'science',
#    'space',
#    'science',
#    'space',
#    'football',
#    'science',
#    'science',
#    'molecula',
#    'debate',
#    'debate',
#    'science',
#    'football',
#    'molecula',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'molecula',
#    'molecula',
#    'debate',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'science',
#    'football',
#    'space',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'debate',
#    'space',
#    'space'],
#   'topics_weights': [('sports', 0.12611646107484564),
#    ('science', 0.8738835389251544)]},
#  {'id': 20,
#   'words': ['football',
#    'space',
#    'twitter',
#    'football',
#    'basketball',
#    'football',
#    'president',
#    'twitter',
#    'twitter',
#    'television',
#    'play',
#    'twitter',
#    'debate',
#    'match',
#    'football',
#    'twitter',
#    'twitter',
#    'president',
#    'president',
#    'twitter',
#    'president',
#    'debate',
#    'space',
#    'president',
#    'football',
#    'space',
#    'space',
#    'match',
#    'president',
#    'twitter',
#    'gol',
#    'play',
#    'football',
#    'space',
#    'president',
#    'twitter',
#    'football',
#    'interview',
#    'twitter',
#    'football',
#    'president',
#    'football',
#    'football',
#    'match',
#    'football',
#    'basketball',
#    'play',
#    'gol',
#    'football',
#    'football',
#    'debate',
#    'football',
#    'television',
#    'twitter',
#    'interview',
#    'football',
#    'football',
#    'space',
#    'football',
#    'twitter',
#    'television',
#    'gol',
#    'gol',
#    'television',
#    'president',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'interview',
#    'twitter',
#    'interview',
#    'debate',
#    'football',
#    'twitter',
#    'gol',
#    'president',
#    'football',
#    'football',
#    'twitter',
#    'football',
#    'debate',
#    'twitter',
#    'space',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'debate',
#    'twitter',
#    'space',
#    'twitter',
#    'play',
#    'space',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'football'],
#   'topics_weights': [('politics', 0.5587321702465892),
#    ('sports', 0.44126782975341083)]},
#  {'id': 21,
#   'words': ['football',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'football',
#    'football',
#    'match',
#    'play',
#    'play',
#    'gol',
#    'space',
#    'football',
#    'space',
#    'football',
#    'football',
#    'gol',
#    'match',
#    'basketball',
#    'play',
#    'football',
#    'football',
#    'football',
#    'space',
#    'space',
#    'gol',
#    'play',
#    'football',
#    'space',
#    'football',
#    'play',
#    'football',
#    'play',
#    'football',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'gol',
#    'football',
#    'space',
#    'football',
#    'football',
#    'football',
#    'play',
#    'space',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'space',
#    'match',
#    'basketball',
#    'football',
#    'gol',
#    'football',
#    'gol',
#    'match',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'football',
#    'science',
#    'match',
#    'football',
#    'space',
#    'basketball',
#    'match',
#    'debate',
#    'football',
#    'football',
#    'basketball',
#    'play',
#    'debate',
#    'gol',
#    'football',
#    'basketball',
#    'gol',
#    'football',
#    'space',
#    'match',
#    'space',
#    'space',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'gol',
#    'gol',
#    'match',
#    'space',
#    'play',
#    'space'],
#   'topics_weights': [('sports', 0.9612999702999451),
#    ('science', 0.03870002970005494)]},
#  {'id': 22,
#   'words': ['debate',
#    'twitter',
#    'debate',
#    'space',
#    'space',
#    'science',
#    'science',
#    'interview',
#    'space',
#    'president',
#    'president',
#    'debate',
#    'space',
#    'twitter',
#    'science',
#    'debate',
#    'twitter',
#    'twitter',
#    'president',
#    'molecula',
#    'space',
#    'twitter',
#    'television',
#    'interview',
#    'science',
#    'president',
#    'twitter',
#    'twitter',
#    'science',
#    'interview',
#    'molecula',
#    'space',
#    'twitter',
#    'space',
#    'space',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'television',
#    'space',
#    'television',
#    'twitter',
#    'interview',
#    'president',
#    'television',
#    'debate',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'interview',
#    'twitter',
#    'president',
#    'television',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'science',
#    'television',
#    'twitter',
#    'twitter',
#    'president',
#    'television',
#    'science',
#    'twitter',
#    'space',
#    'debate',
#    'twitter',
#    'space',
#    'space',
#    'molecula',
#    'interview',
#    'debate',
#    'interview',
#    'twitter',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'space',
#    'molecula',
#    'president',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'debate'],
#   'topics_weights': [('science', 0.28577860433834457),
#    ('politics', 0.7142213956616554)]},
#  {'id': 23,
#   'words': ['twitter',
#    'television',
#    'football',
#    'twitter',
#    'basketball',
#    'football',
#    'football',
#    'debate',
#    'twitter',
#    'play',
#    'space',
#    'football',
#    'space',
#    'twitter',
#    'play',
#    'space',
#    'basketball',
#    'gol',
#    'space',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'space',
#    'gol',
#    'space',
#    'twitter',
#    'gol',
#    'twitter',
#    'president',
#    'match',
#    'football',
#    'football',
#    'football',
#    'football',
#    'play',
#    'debate',
#    'interview',
#    'twitter',
#    'football',
#    'president',
#    'play',
#    'space',
#    'space',
#    'football',
#    'president',
#    'play',
#    'twitter',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'play',
#    'play',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'football',
#    'football',
#    'match',
#    'twitter',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'match',
#    'football',
#    'space',
#    'match',
#    'gol',
#    'gol',
#    'space',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'gol',
#    'gol',
#    'basketball',
#    'debate',
#    'twitter',
#    'president',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'gol',
#    'space',
#    'gol',
#    'television',
#    'play',
#    'play',
#    'basketball',
#    'football',
#    'twitter',
#    'television'],
#   'topics_weights': [('politics', 0.4425989821111376),
#    ('sports', 0.5574010178888624)]},
#  {'id': 24,
#   'words': ['molecula',
#    'debate',
#    'molecula',
#    'debate',
#    'gol',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'match',
#    'molecula',
#    'molecula',
#    'debate',
#    'debate',
#    'gol',
#    'science',
#    'football',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'science',
#    'debate',
#    'football',
#    'basketball',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'science',
#    'science',
#    'football',
#    'play',
#    'molecula',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'football',
#    'space',
#    'space',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'play',
#    'debate',
#    'debate',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'molecula',
#    'molecula',
#    'science',
#    'space',
#    'play',
#    'gol',
#    'science',
#    'molecula',
#    'football',
#    'space',
#    'space',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'space',
#    'football',
#    'basketball',
#    'space',
#    'molecula',
#    'gol',
#    'molecula',
#    'play',
#    'molecula',
#    'molecula',
#    'space',
#    'play',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'space'],
#   'topics_weights': [('science', 0.7707624635430746),
#    ('sports', 0.22923753645692538)]},
#  {'id': 25,
#   'words': ['molecula',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'match',
#    'debate',
#    'space',
#    'debate',
#    'science',
#    'debate',
#    'science',
#    'football',
#    'football',
#    'molecula',
#    'molecula',
#    'space',
#    'science',
#    'science',
#    'space',
#    'science',
#    'space',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'play',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'debate',
#    'molecula',
#    'debate',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'basketball',
#    'science',
#    'space',
#    'molecula',
#    'gol',
#    'molecula',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'molecula',
#    'football',
#    'space',
#    'debate',
#    'molecula',
#    'football',
#    'match',
#    'space',
#    'space',
#    'football',
#    'science',
#    'debate',
#    'science',
#    'debate',
#    'gol',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'science',
#    'molecula',
#    'molecula',
#    'molecula',
#    'football',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'football',
#    'debate',
#    'debate'],
#   'topics_weights': [('sports', 0.1354304986637951),
#    ('science', 0.8645695013362049)]},
#  {'id': 26,
#   'words': ['play',
#    'play',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'basketball',
#    'gol',
#    'twitter',
#    'football',
#    'twitter',
#    'gol',
#    'football',
#    'match',
#    'football',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'gol',
#    'space',
#    'football',
#    'president',
#    'gol',
#    'television',
#    'football',
#    'football',
#    'match',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'president',
#    'twitter',
#    'basketball',
#    'twitter',
#    'football',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'television',
#    'football',
#    'space',
#    'space',
#    'interview',
#    'president',
#    'football',
#    'twitter',
#    'match',
#    'match',
#    'twitter',
#    'football',
#    'play',
#    'interview',
#    'football',
#    'football',
#    'basketball',
#    'space',
#    'gol',
#    'football',
#    'television',
#    'space',
#    'twitter',
#    'play',
#    'twitter',
#    'twitter',
#    'basketball',
#    'debate',
#    'football',
#    'debate',
#    'space',
#    'president',
#    'football',
#    'debate',
#    'space',
#    'gol',
#    'space',
#    'football',
#    'gol',
#    'space',
#    'twitter',
#    'football',
#    'president',
#    'space',
#    'basketball',
#    'interview',
#    'football',
#    'twitter',
#    'twitter',
#    'president',
#    'interview',
#    'space',
#    'football',
#    'space',
#    'twitter',
#    'football',
#    'interview',
#    'football'],
#   'topics_weights': [('politics', 0.4396487299049515),
#    ('sports', 0.5603512700950485)]},
#  {'id': 27,
#   'words': ['twitter',
#    'television',
#    'president',
#    'interview',
#    'space',
#    'television',
#    'president',
#    'twitter',
#    'twitter',
#    'television',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'television',
#    'president',
#    'debate',
#    'twitter',
#    'interview',
#    'president',
#    'debate',
#    'television',
#    'twitter',
#    'twitter',
#    'debate',
#    'president',
#    'football',
#    'president',
#    'twitter',
#    'twitter',
#    'interview',
#    'president',
#    'television',
#    'interview',
#    'twitter',
#    'president',
#    'television',
#    'twitter',
#    'twitter',
#    'interview',
#    'interview',
#    'television',
#    'twitter',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'president',
#    'president',
#    'president',
#    'interview',
#    'twitter',
#    'president',
#    'debate',
#    'president',
#    'interview',
#    'president',
#    'president',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'president',
#    'twitter',
#    'president',
#    'president',
#    'president',
#    'television',
#    'debate',
#    'twitter',
#    'twitter',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'space',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'television',
#    'president',
#    'debate',
#    'president',
#    'president',
#    'space',
#    'twitter',
#    'interview',
#    'interview',
#    'president'],
#   'topics_weights': [('politics', 0.975757969237493),
#    ('sports', 0.024242030762507014)]},
#  {'id': 28,
#   'words': ['football',
#    'space',
#    'football',
#    'space',
#    'science',
#    'molecula',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'play',
#    'space',
#    'football',
#    'space',
#    'play',
#    'gol',
#    'gol',
#    'basketball',
#    'molecula',
#    'debate',
#    'basketball',
#    'football',
#    'football',
#    'molecula',
#    'football',
#    'science',
#    'football',
#    'space',
#    'science',
#    'match',
#    'space',
#    'space',
#    'debate',
#    'football',
#    'space',
#    'space',
#    'football',
#    'science',
#    'gol',
#    'molecula',
#    'football',
#    'debate',
#    'football',
#    'science',
#    'science',
#    'science',
#    'match',
#    'molecula',
#    'space',
#    'play',
#    'space',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'gol',
#    'molecula',
#    'molecula',
#    'space',
#    'space',
#    'basketball',
#    'football',
#    'gol',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'space',
#    'molecula',
#    'debate',
#    'play',
#    'gol',
#    'science',
#    'football',
#    'molecula',
#    'science',
#    'play',
#    'molecula',
#    'science',
#    'science',
#    'molecula',
#    'football',
#    'space',
#    'debate',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'basketball',
#    'debate',
#    'molecula',
#    'play',
#    'science',
#    'debate',
#    'space'],
#   'topics_weights': [('science', 0.5128525864991107),
#    ('sports', 0.4871474135008893)]},
#  {'id': 29,
#   'words': ['television',
#    'match',
#    'basketball',
#    'twitter',
#    'football',
#    'president',
#    'football',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'basketball',
#    'twitter',
#    'president',
#    'twitter',
#    'television',
#    'twitter',
#    'president',
#    'gol',
#    'basketball',
#    'president',
#    'twitter',
#    'gol',
#    'television',
#    'twitter',
#    'president',
#    'president',
#    'space',
#    'twitter',
#    'play',
#    'football',
#    'gol',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'football',
#    'president',
#    'play',
#    'gol',
#    'twitter',
#    'space',
#    'football',
#    'space',
#    'president',
#    'president',
#    'interview',
#    'play',
#    'twitter',
#    'space',
#    'space',
#    'football',
#    'president',
#    'match',
#    'space',
#    'interview',
#    'football',
#    'basketball',
#    'debate',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'play',
#    'twitter',
#    'interview',
#    'space',
#    'twitter',
#    'president',
#    'space',
#    'play',
#    'twitter',
#    'television',
#    'president',
#    'gol',
#    'president',
#    'twitter',
#    'space',
#    'debate',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'match',
#    'interview',
#    'play',
#    'football',
#    'football',
#    'football',
#    'twitter',
#    'football',
#    'interview',
#    'basketball',
#    'twitter',
#    'twitter'],
#   'topics_weights': [('politics', 0.6647678000736024),
#    ('sports', 0.33523219992639763)]},
#  {'id': 30,
#   'words': ['twitter',
#    'molecula',
#    'television',
#    'debate',
#    'debate',
#    'debate',
#    'twitter',
#    'debate',
#    'science',
#    'twitter',
#    'debate',
#    'president',
#    'twitter',
#    'twitter',
#    'molecula',
#    'debate',
#    'molecula',
#    'television',
#    'debate',
#    'science',
#    'debate',
#    'debate',
#    'twitter',
#    'television',
#    'president',
#    'twitter',
#    'space',
#    'debate',
#    'television',
#    'president',
#    'interview',
#    'molecula',
#    'debate',
#    'space',
#    'twitter',
#    'space',
#    'debate',
#    'debate',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'president',
#    'space',
#    'debate',
#    'debate',
#    'president',
#    'twitter',
#    'interview',
#    'debate',
#    'molecula',
#    'twitter',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'debate',
#    'president',
#    'debate',
#    'interview',
#    'space',
#    'president',
#    'twitter',
#    'debate',
#    'twitter',
#    'space',
#    'twitter',
#    'science',
#    'debate',
#    'molecula',
#    'science',
#    'interview',
#    'television',
#    'television',
#    'molecula',
#    'twitter',
#    'television',
#    'twitter',
#    'television',
#    'space',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'science',
#    'television',
#    'interview',
#    'molecula',
#    'twitter',
#    'twitter',
#    'president',
#    'debate',
#    'president',
#    'television',
#    'twitter',
#    'space',
#    'molecula',
#    'science',
#    'interview',
#    'science'],
#   'topics_weights': [('science', 0.3725777746657344),
#    ('politics', 0.6274222253342656)]},
#  {'id': 31,
#   'words': ['president',
#    'president',
#    'twitter',
#    'science',
#    'debate',
#    'science',
#    'twitter',
#    'debate',
#    'debate',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'molecula',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'space',
#    'twitter',
#    'science',
#    'twitter',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'science',
#    'twitter',
#    'president',
#    'debate',
#    'television',
#    'television',
#    'debate',
#    'debate',
#    'twitter',
#    'science',
#    'president',
#    'twitter',
#    'molecula',
#    'president',
#    'space',
#    'space',
#    'television',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'twitter',
#    'space',
#    'interview',
#    'space',
#    'space',
#    'twitter',
#    'molecula',
#    'space',
#    'space',
#    'debate',
#    'twitter',
#    'television',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'president',
#    'debate',
#    'science',
#    'debate',
#    'debate',
#    'twitter',
#    'molecula',
#    'television',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'debate',
#    'president',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'space',
#    'interview'],
#   'topics_weights': [('science', 0.6811267050807079),
#    ('politics', 0.3188732949192921)]},
#  {'id': 32,
#   'words': ['football',
# ...
#    'science',
#    'football',
#    'science',
#    'science',
#    'molecula',
#    'football',
#    'space',
#    'science',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'football',
#    'football',
#    'debate',
#    'debate',
#    'science',
#    'match',
#    'debate',
#    'football',
#    'molecula',
#    'football',
#    'space',
#    'basketball',
#    'gol',
#    'space',
#    'space',
#    'play',
#    'space',
#    'space',
#    'space',
#    'molecula',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'match',
#    'science',
#    'debate',
#    'debate',
#    'football',
#    'football',
#    'science',
#    'science',
#    'football',
#    'space',
#    'debate',
#    'football',
#    'science',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'space'],
#   'topics_weights': [('sports', 0.4004656004885727),
#    ('science', 0.5995343995114273)]},
#  {'id': 90,
#   'words': ['molecula',
#    'twitter',
#    'molecula',
#    'science',
#    'twitter',
#    'debate',
#    'space',
#    'space',
#    'interview',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'molecula',
#    'twitter',
#    'twitter',
#    'interview',
#    'debate',
#    'twitter',
#    'molecula',
#    'television',
#    'science',
#    'president',
#    'twitter',
#    'president',
#    'debate',
#    'debate',
#    'twitter',
#    'science',
#    'space',
#    'interview',
#    'twitter',
#    'twitter',
#    'television',
#    'debate',
#    'television',
#    'space',
#    'television',
#    'twitter',
#    'interview',
#    'space',
#    'president',
#    'television',
#    'molecula',
#    'science',
#    'twitter',
#    'molecula',
#    'molecula',
#    'science',
#    'space',
#    'president',
#    'science',
#    'twitter',
#    'television',
#    'twitter',
#    'space',
#    'science',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'space',
#    'interview',
#    'twitter',
#    'twitter',
#    'science',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'debate',
#    'space',
#    'space',
#    'president',
#    'debate',
#    'twitter',
#    'debate',
#    'space',
#    'space',
#    'molecula',
#    'president',
#    'molecula',
#    'debate',
#    'twitter',
#    'debate',
#    'television',
#    'president',
#    'molecula',
#    'debate',
#    'science',
#    'science',
#    'science',
#    'television',
#    'debate',
#    'molecula',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter'],
#   'topics_weights': [('politics', 0.586182094335468),
#    ('science', 0.4138179056645321)]},
#  {'id': 91,
#   'words': ['football',
#    'interview',
#    'twitter',
#    'football',
#    'football',
#    'president',
#    'television',
#    'twitter',
#    'basketball',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'interview',
#    'television',
#    'twitter',
#    'interview',
#    'football',
#    'play',
#    'football',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'football',
#    'space',
#    'president',
#    'twitter',
#    'television',
#    'twitter',
#    'gol',
#    'basketball',
#    'president',
#    'space',
#    'interview',
#    'president',
#    'football',
#    'twitter',
#    'debate',
#    'space',
#    'match',
#    'twitter',
#    'space',
#    'space',
#    'president',
#    'space',
#    'football',
#    'interview',
#    'space',
#    'president',
#    'interview',
#    'basketball',
#    'debate',
#    'president',
#    'twitter',
#    'basketball',
#    'twitter',
#    'space',
#    'basketball',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'debate',
#    'television',
#    'interview',
#    'twitter',
#    'play',
#    'interview',
#    'interview',
#    'president',
#    'president',
#    'twitter',
#    'space',
#    'debate',
#    'president',
#    'play',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'debate',
#    'basketball',
#    'television',
#    'twitter',
#    'president',
#    'space',
#    'twitter',
#    'debate',
#    'football',
#    'twitter',
#    'twitter',
#    'president',
#    'football',
#    'space',
#    'president',
#    'interview',
#    'twitter',
#    'debate',
#    'twitter'],
#   'topics_weights': [('politics', 0.7147467995979435),
#    ('sports', 0.28525320040205643)]},
#  {'id': 92,
#   'words': ['molecula',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'space',
#    'football',
#    'space',
#    'space',
#    'space',
#    'science',
#    'play',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'molecula',
#    'football',
#    'debate',
#    'gol',
#    'debate',
#    'space',
#    'science',
#    'football',
#    'science',
#    'football',
#    'football',
#    'molecula',
#    'science',
#    'debate',
#    'molecula',
#    'match',
#    'science',
#    'science',
#    'molecula',
#    'match',
#    'football',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'gol',
#    'debate',
#    'football',
#    'space',
#    'space',
#    'football',
#    'molecula',
#    'science',
#    'football',
#    'science',
#    'football',
#    'science',
#    'football',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'play',
#    'molecula',
#    'space',
#    'molecula',
#    'play',
#    'space',
#    'molecula',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'gol',
#    'space',
#    'molecula',
#    'football',
#    'match',
#    'molecula',
#    'molecula',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'space',
#    'basketball',
#    'molecula',
#    'basketball',
#    'science',
#    'match',
#    'molecula',
#    'gol',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'football'],
#   'topics_weights': [('sports', 0.2897372545821831),
#    ('science', 0.710262745417817)]},
#  {'id': 93,
#   'words': ['interview',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'television',
#    'gol',
#    'gol',
#    'president',
#    'interview',
#    'twitter',
#    'play',
#    'interview',
#    'television',
#    'basketball',
#    'television',
#    'football',
#    'twitter',
#    'space',
#    'television',
#    'match',
#    'twitter',
#    'space',
#    'interview',
#    'television',
#    'play',
#    'president',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'television',
#    'twitter',
#    'president',
#    'president',
#    'play',
#    'debate',
#    'twitter',
#    'play',
#    'twitter',
#    'interview',
#    'debate',
#    'football',
#    'football',
#    'football',
#    'match',
#    'television',
#    'president',
#    'football',
#    'twitter',
#    'basketball',
#    'twitter',
#    'president',
#    'interview',
#    'television',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'football',
#    'president',
#    'president',
#    'football',
#    'television',
#    'match',
#    'twitter',
#    'debate',
#    'president',
#    'football',
#    'television',
#    'president',
#    'space',
#    'president',
#    'twitter',
#    'president',
#    'basketball',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'twitter',
#    'gol',
#    'basketball',
#    'play',
#    'twitter',
#    'television',
#    'football',
#    'television',
#    'space',
#    'match',
#    'twitter'],
#   'topics_weights': [('politics', 0.6659494941064245),
#    ('sports', 0.3340505058935756)]},
#  {'id': 94,
#   'words': ['space',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'science',
#    'debate',
#    'space',
#    'space',
#    'science',
#    'space',
#    'space',
#    'space',
#    'debate',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'space',
#    'science',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'debate',
#    'debate',
#    'debate',
#    'president',
#    'science',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'debate',
#    'television',
#    'debate',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'twitter',
#    'molecula',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'space',
#    'space',
#    'television',
#    'interview',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'twitter',
#    'space',
#    'molecula',
#    'molecula',
#    'twitter',
#    'molecula',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'debate',
#    'president',
#    'space',
#    'space',
#    'science',
#    'debate',
#    'science',
#    'molecula',
#    'molecula',
#    'science',
#    'debate',
#    'debate',
#    'science',
#    'molecula',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'space',
#    'molecula',
#    'president',
#    'science',
#    'space',
#    'science',
#    'molecula'],
#   'topics_weights': [('politics', 0.07216919386868803),
#    ('science', 0.927830806131312)]},
#  {'id': 95,
#   'words': ['twitter',
#    'interview',
#    'twitter',
#    'space',
#    'president',
#    'television',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'president',
#    'president',
#    'space',
#    'debate',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'president',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'space',
#    'twitter',
#    'president',
#    'space',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'twitter',
#    'president',
#    'twitter',
#    'debate',
#    'president',
#    'television',
#    'twitter',
#    'president',
#    'television',
#    'television',
#    'twitter',
#    'president',
#    'president',
#    'president',
#    'debate',
#    'president',
#    'president',
#    'debate',
#    'interview',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'interview',
#    'television',
#    'television',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'television',
#    'debate',
#    'interview',
#    'twitter',
#    'twitter',
#    'television',
#    'debate',
#    'president',
#    'debate',
#    'president',
#    'space',
#    'space',
#    'television',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'television',
#    'president',
#    'space',
#    'television',
#    'debate',
#    'debate',
#    'twitter'],
#   'topics_weights': [('politics', 0.9967620729476551),
#    ('sports', 0.003237927052344966)]},
#  {'id': 96,
#   'words': ['debate',
#    'debate',
#    'molecula',
#    'twitter',
#    'science',
#    'molecula',
#    'debate',
#    'twitter',
#    'debate',
#    'molecula',
#    'molecula',
#    'debate',
#    'space',
#    'science',
#    'space',
#    'interview',
#    'debate',
#    'science',
#    'molecula',
#    'debate',
#    'science',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'twitter',
#    'president',
#    'twitter',
#    'interview',
#    'science',
#    'debate',
#    'science',
#    'twitter',
#    'space',
#    'science',
#    'twitter',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'science',
#    'debate',
#    'president',
#    'space',
#    'molecula',
#    'space',
#    'science',
#    'molecula',
#    'debate',
#    'debate',
#    'space',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'science',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'space',
#    'twitter',
#    'twitter',
#    'science',
#    'science',
#    'science',
#    'molecula',
#    'science',
#    'molecula',
#    'molecula',
#    'science',
#    'debate',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'molecula',
#    'science',
#    'debate',
#    'debate',
#    'space',
#    'debate'],
#   'topics_weights': [('politics', 0.18321309025262963),
#    ('science', 0.8167869097473703)]},
#  {'id': 97,
#   'words': ['twitter',
#    'twitter',
#    'match',
#    'twitter',
#    'twitter',
#    'president',
#    'football',
#    'play',
#    'gol',
#    'twitter',
#    'football',
#    'match',
#    'president',
#    'football',
#    'space',
#    'basketball',
#    'television',
#    'basketball',
#    'space',
#    'space',
#    'match',
#    'president',
#    'twitter',
#    'basketball',
#    'football',
#    'twitter',
#    'match',
#    'football',
#    'football',
#    'football',
#    'interview',
#    'gol',
#    'space',
#    'interview',
#    'gol',
#    'president',
#    'twitter',
#    'space',
#    'interview',
#    'gol',
#    'gol',
#    'football',
#    'television',
#    'basketball',
#    'football',
#    'basketball',
#    'basketball',
#    'space',
#    'basketball',
#    'twitter',
#    'space',
#    'president',
#    'gol',
#    'twitter',
#    'debate',
#    'match',
#    'football',
#    'interview',
#    'football',
#    'debate',
#    'twitter',
#    'twitter',
#    'debate',
#    'match',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'football',
#    'president',
#    'space',
#    'twitter',
#    'president',
#    'space',
#    'basketball',
#    'gol',
#    'twitter',
#    'football',
#    'twitter',
#    'television',
#    'twitter',
#    'play',
#    'interview',
#    'football',
#    'space',
#    'space',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'gol',
#    'match',
#    'space',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'space'],
#   'topics_weights': [('politics', 0.5563013899930032),
#    ('sports', 0.44369861000699684)]},
#  {'id': 98,
#   'words': ['basketball',
#    'match',
#    'basketball',
#    'football',
#    'molecula',
#    'debate',
#    'space',
#    'football',
#    'play',
#    'science',
#    'basketball',
#    'debate',
#    'gol',
#    'football',
#    'debate',
#    'molecula',
#    'gol',
#    'science',
#    'basketball',
#    'science',
#    'basketball',
#    'match',
#    'football',
#    'football',
#    'science',
#    'match',
#    'space',
#    'space',
#    'space',
#    'football',
#    'space',
#    'football',
#    'football',
#    'space',
#    'football',
#    'space',
#    'football',
#    'play',
#    'space',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'debate',
#    'match',
#    'football',
#    'molecula',
#    'gol',
#    'science',
#    'basketball',
#    'science',
#    'football',
#    'debate',
#    'molecula',
#    'match',
#    'science',
#    'football',
#    'football',
#    'football',
#    'football',
#    'basketball',
#    'play',
#    'space',
#    'play',
#    'gol',
#    'space',
#    'football',
#    'match',
#    'football',
#    'molecula',
#    'debate',
#    'play',
#    'molecula',
#    'space',
#    'space',
#    'play',
#    'basketball',
#    'match',
#    'space',
#    'space',
#    'match',
#    'match',
#    'debate',
#    'space',
#    'play',
#    'space',
#    'molecula',
#    'molecula',
#    'space',
#    'football',
#    'match',
#    'play',
#    'football',
#    'basketball',
#    'space',
#    'gol',
#    'molecula',
#    'play',
#    'science'],
#   'topics_weights': [('sports', 0.6587298976155465),
#    ('science', 0.3412701023844537)]},
#  {'id': 99,
#   'words': ['football',
#    'match',
#    'gol',
#    'football',
#    'debate',
#    'football',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'interview',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'football',
#    'television',
#    'president',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'gol',
#    'twitter',
#    'space',
#    'twitter',
#    'play',
#    'twitter',
#    'president',
#    'interview',
#    'football',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'match',
#    'debate',
#    'debate',
#    'president',
#    'twitter',
#    'president',
#    'football',
#    'twitter',
#    'space',
#    'match',
#    'space',
#    'gol',
#    'president',
#    'twitter',
#    'twitter',
#    'football',
#    'television',
#    'twitter',
#    'president',
#    'debate',
#    'football',
#    'twitter',
#    'football',
#    'interview',
#    'twitter',
#    'play',
#    'football',
#    'twitter',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'basketball',
#    'play',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'football',
#    'match',
#    'interview',
#    'twitter',
#    'basketball',
#    'president',
#    'twitter',
#    'twitter',
#    'play',
#    'football',
#    'twitter',
#    'debate',
#    'interview',
#    'twitter',
#    'president',
#    'gol',
#    'play',
#    'basketball',
#    'twitter',
#    'twitter',
#    'president',
#    'football',
#    'twitter',
#    'twitter'],
#   'topics_weights': [('sports', 0.3761768754815214),
#    ('politics', 0.6238231245184787)]}]

# %% [markdown]
# ## Generar tablas auxiliares: words vs topics, docs vs topics

# %%
def words_vs_topics_matrix(docs, words_idx, ntopics):
    m = np.zeros((len(words_idx), ntopics))
    for doc in docs:
        for a in doc['assignment']:
            word_j = words_idx.index(a['word'])
            m[word_j, a['topic']] += 1
    return m


def docs_vs_topics_matrix(docs, ntopics):
    m = np.zeros((len(docs), ntopics))
    for doc in docs:
        doc_i = docs.index(doc)
        for a in doc['assignment']:
            m[doc_i, a['topic']] += 1
    return m


def random_assignment(docs, ntopics):
    for doc in docs:
        assignment = zip(doc['words'], np.random.randint(0, ntopics, len(doc['words'])))  # get random initial assignment for each word in each document
        doc['assignment'] = [{'word': t[0], 'topic': t[1]} for t in assignment]
    

test_docs = [
    {'id': 0, 'assignment': [{'word': 'A', 'topic': 0}, {'word': 'AA', 'topic': 0}]},
    {'id': 1, 'assignment': [{'word': 'B', 'topic': 1}, {'word': 'BB', 'topic': 1}]},
]

# TEST
words_vs_topics_matrix(test_docs, words_idx=['A', 'AA', 'B', 'BB'], ntopics=2) == np.array([[1,0],[1,0],[0,1],[0,1]])
# Out:
# array([[ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True]])

# %% [markdown]
# ## Dirichlet allocation versión lenta

# %%
def prob_w_belongs_t_in_d(words_vs_topics, docs_vs_topics, d, w, t, old_topic, alpha, beta, debug=False):
    # P(w belongs topic) = P(word w | topic t) * P(topic t | doc d)
    # P(w belongs topic) = Proporcion(word w en el topic t) * Proporcion(topic t en el doc d)
    # prob_w_belongs_t = words_vs_topics[w, t]/words_vs_topics[:, t] * docs_vs_topics[d, t]/sum(docs_vs_topic[d, :])
    nwords, ntopics = words_vs_topics.shape
    ndocs, _ = docs_vs_topics.shape
        
    if debug:
        print("words_vs_topics=\n", words_vs_topics, words_vs_topics[w, t], (w,t))
        print("docs_vs_topics=\n", docs_vs_topics, docs_vs_topics[d, t], (d,t))
        print("t=", t)
        print("d=", d)
        print("w=", w)
        print("old_topic=", old_topic)
    
    if old_topic == t:
        # Note: as we are calculating the new topic assignation for w, we need to eliminate the
        # old assignation. That is why we rest -1 in those calculations
        assert words_vs_topics[w, t] > 0
        assert docs_vs_topics[d, t] > 0
        if debug:
            print("REMOVING OLD ASIGNATION")
            print((words_vs_topics[w, t]-1 + beta)/(sum(words_vs_topics[:, t])-1 + beta*nwords))
            print((docs_vs_topics[d, t]-1 + alpha)/(sum(docs_vs_topics[d, :])-1 + alpha*ntopics))
            input()
        return (words_vs_topics[w, t]-1 + beta)/(sum(words_vs_topics[:, t])-1 + beta*nwords) \
               * (docs_vs_topics[d, t]-1 + alpha)/(sum(docs_vs_topics[d, :])-1 + alpha*ntopics)
    else:
        if debug:
            print((words_vs_topics[w, t] + beta)/(sum(words_vs_topics[:, t]) + beta))
            print((docs_vs_topics[d, t] + alpha)/(sum(docs_vs_topics[d, :]) + alpha*ntopics))
            input()
        return (words_vs_topics[w, t] + beta)/(sum(words_vs_topics[:, t]) + beta) \
               * (docs_vs_topics[d, t] + alpha)/(sum(docs_vs_topics[d, :]) + alpha*ntopics)


def dirichlet_allocation(docs, docs_idx, words_idx, ntopics, niter=400, alpha=0.5, beta=0.01, debug=False):
    ndocs, nwords = len(docs_idx), len(words_idx)

    random_assignment(docs, ntopics)

    for _ in range(niter):

        words_vs_topics = words_vs_topics_matrix(docs, words_idx, ntopics)
        # print(words_vs_topics)

        docs_vs_topics = docs_vs_topics_matrix(docs, ntopics)
        # print(docs_vs_topics)

        for doc in docs:
            doc_i = docs_idx.index(doc['id'])
            for assign in doc['assignment']:
                word = assign['word']
                word_j = words_idx.index(word)
                old_topic = assign['topic']
                prob_by_topic = [0] * ntopics  # unnormalized
                for topic_k in range(ntopics):
                    if debug:
                        print(f"==>> doc {doc_i}, word {word_j}, calculating for topic {topic_k} (old topic was {old_topic})")
                    p = prob_w_belongs_t_in_d(words_vs_topics, docs_vs_topics, doc_i, word_j, topic_k, old_topic=old_topic, alpha=alpha, beta=beta, debug=debug)
                    prob_by_topic[topic_k] = p

                new_topic = random.choices(range(ntopics), prob_by_topic, k=1)[0]
                assign['topic'] = new_topic

    return docs


docs = dirichlet_allocation(docs, docs_idx, words_idx, ntopics=3, niter=100)
# docs

# %%
def normalize_counter(c):
    total = sum(c.values(), 0.0)
    for key in c:
        c[key] /= total
    return c

for (i, d) in enumerate(docs):
    print(i, d['topics_weights'])
    topic_list = Counter([a['topic'] for a in d['assignment']])
    a = normalize_counter(Counter(topic_list))
    print(i, sorted(a.items()))
# Out:
# 0 [('science', 0.24456755248379008), ('sports', 0.75543244751621)]
# 0 [(0, 0.01), (1, 0.77), (2, 0.22)]
# 1 [('sports', 0.35727722282000307), ('politics', 0.6427227771799969)]
# 1 [(0, 0.62), (1, 0.37), (2, 0.01)]
# 2 [('sports', 0.542989916612604), ('science', 0.45701008338739607)]
# 2 [(1, 0.56), (2, 0.44)]
# 3 [('science', 0.39538758109917665), ('sports', 0.6046124189008233)]
# 3 [(1, 0.67), (2, 0.33)]
# 4 [('science', 0.07236994958194534), ('sports', 0.9276300504180547)]
# 4 [(0, 0.01), (1, 0.92), (2, 0.07)]
# 5 [('sports', 0.43887033509303514), ('politics', 0.5611296649069649)]
# 5 [(0, 0.58), (1, 0.42)]
# 6 [('sports', 0.11407328212216619), ('politics', 0.8859267178778338)]
# 6 [(0, 0.92), (1, 0.08)]
# 7 [('science', 0.6406622574014711), ('sports', 0.3593377425985289)]
# 7 [(1, 0.35), (2, 0.65)]
# 8 [('science', 0.09343523903964185), ('sports', 0.9065647609603581)]
# 8 [(1, 0.93), (2, 0.07)]
# 9 [('sports', 0.4143566061847329), ('science', 0.5856433938152672)]
# 9 [(1, 0.42), (2, 0.58)]
# 10 [('science', 0.5936265713383261), ('politics', 0.40637342866167403)]
# 10 [(0, 0.4), (2, 0.6)]
# 11 [('politics', 0.5305417543340212), ('sports', 0.46945824566597877)]
# 11 [(0, 0.5), (1, 0.5)]
# 12 [('sports', 0.415927780693171), ('science', 0.584072219306829)]
# 12 [(1, 0.43), (2, 0.57)]
# 13 [('science', 0.6011752452866223), ('politics', 0.3988247547133778)]
# 13 [(0, 0.5), (2, 0.5)]
# 14 [('sports', 0.6017576169801229), ('politics', 0.39824238301987713)]
# 14 [(0, 0.47), (1, 0.53)]
# 15 [('sports', 0.8546393923286264), ('science', 0.1453606076713736)]
# 15 [(1, 0.79), (2, 0.21)]
# 16 [('science', 0.5514140698624164), ('sports', 0.4485859301375837)]
# 16 [(1, 0.44), (2, 0.56)]
# 17 [('sports', 0.5966290926432847), ('politics', 0.40337090735671544)]
# 17 [(0, 0.38), (1, 0.62)]
# 18 [('science', 0.6074891321791508), ('politics', 0.3925108678208492)]
# 18 [(0, 0.39), (2, 0.61)]
# 19 [('science', 0.4397688812367044), ('politics', 0.5602311187632957)]
# 19 [(0, 0.54), (2, 0.46)]
# 20 [('science', 0.5143138390787939), ('politics', 0.48568616092120614)]
# 20 [(0, 0.52), (1, 0.01), (2, 0.47)]
# 21 [('sports', 0.4672941811111519), ('science', 0.532705818888848)]
# 21 [(1, 0.4), (2, 0.6)]
# 22 [('sports', 0.6562838766968819), ('science', 0.3437161233031181)]
# 22 [(1, 0.68), (2, 0.32)]
# 23 [('sports', 0.8664036037523462), ('science', 0.13359639624765388)]
# 23 [(1, 0.93), (2, 0.07)]
# 24 [('science', 0.6942934972171066), ('sports', 0.30570650278289335)]
# 24 [(1, 0.3), (2, 0.7)]
# 25 [('sports', 0.7101977854153113), ('politics', 0.28980221458468874)]
# 25 [(0, 0.25), (1, 0.75)]
# 26 [('science', 0.7113156066986488), ('sports', 0.2886843933013511)]
# 26 [(1, 0.25), (2, 0.75)]
# 27 [('science', 0.8677584672048038), ('politics', 0.13224153279519626)]
# 27 [(0, 0.06), (1, 0.01), (2, 0.93)]
# 28 [('politics', 0.21769194798450933), ('science', 0.7823080520154907)]
# 28 [(0, 0.24), (2, 0.76)]
# 29 [('science', 0.6026340575083013), ('sports', 0.3973659424916986)]
# 29 [(0, 0.01), (1, 0.43), (2, 0.56)]
# 30 [('politics', 0.38074113082862276), ('sports', 0.6192588691713773)]
# 30 [(0, 0.34), (1, 0.65), (2, 0.01)]
# 31 [('sports', 0.6073445395886145), ('science', 0.3926554604113856)]
# 31 [(1, 0.54), (2, 0.46)]
# 32 [('science', 0.6849642249628335), ('sports', 0.3150357750371665)]
# 32 [(1, 0.3), (2, 0.7)]
# 33 [('politics', 0.21469340080810173), ('science', 0.7853065991918983)]
# 33 [(0, 0.23), (2, 0.77)]
# 34 [('sports', 0.9271496199440428), ('science', 0.07285038005595727)]
# 34 [(1, 0.87), (2, 0.13)]
# 35 [('politics', 0.48720166170377543), ('science', 0.5127983382962246)]
# 35 [(0, 0.44), (2, 0.56)]
# 36 [('politics', 0.2395931747025802), ('science', 0.7604068252974198)]
# 36 [(0, 0.22), (2, 0.78)]
# 37 [('politics', 0.661487665921507), ('science', 0.33851233407849296)]
# 37 [(0, 0.62), (2, 0.38)]
# 38 [('politics', 0.04873360714546357), ('sports', 0.9512663928545364)]
# 38 [(0, 0.04), (1, 0.95), (2, 0.01)]
# 39 [('sports', 0.6467751006370329), ('science', 0.353224899362967)]
# 39 [(1, 0.73), (2, 0.27)]
# 40 [('science', 0.5234115415742353), ('politics', 0.47658845842576475)]
# 40 [(0, 0.45), (2, 0.55)]
# 41 [('sports', 0.5667582248714024), ('politics', 0.4332417751285975)]
# 41 [(0, 0.41), (1, 0.59)]
# 42 [('sports', 0.31054793565491806), ('science', 0.6894520643450819)]
# 42 [(1, 0.41), (2, 0.59)]
# 43 [('politics', 0.41488801200791653), ('sports', 0.5851119879920835)]
# 43 [(0, 0.31), (1, 0.69)]
# 44 [('science', 0.10736481024090286), ('sports', 0.8926351897590972)]
# 44 [(1, 0.95), (2, 0.05)]
# 45 [('science', 0.5862304393618908), ('sports', 0.4137695606381092)]
# 45 [(0, 0.01), (1, 0.33), (2, 0.66)]
# 46 [('sports', 0.7854839339939971), ('science', 0.21451606600600298)]
# 46 [(1, 0.84), (2, 0.16)]
# 47 [('politics', 0.04291130306186831), ('science', 0.9570886969381317)]
# 47 [(0, 0.05), (2, 0.95)]
# 48 [('sports', 0.4930279149809849), ('politics', 0.5069720850190151)]
# 48 [(0, 0.5), (1, 0.5)]
# 49 [('politics', 0.047472453582390696), ('science', 0.9525275464176093)]
# 49 [(0, 0.08), (2, 0.92)]
# 50 [('sports', 0.5945294672825318), ('science', 0.4054705327174683)]
# 50 [(1, 0.69), (2, 0.31)]
# 51 [('science', 0.5163734052552731), ('politics', 0.4836265947447269)]
# 51 [(0, 0.56), (2, 0.44)]
# 52 [('science', 0.4088268397730415), ('sports', 0.5911731602269584)]
# 52 [(1, 0.64), (2, 0.36)]
# 53 [('sports', 0.4780641398686021), ('politics', 0.5219358601313979)]
# 53 [(0, 0.51), (1, 0.49)]
# 54 [('science', 0.9925225508345576), ('sports', 0.007477449165442351)]
# 54 [(2, 1.0)]
# 55 [('politics', 0.5067738041464146), ('sports', 0.4932261958535854)]
# 55 [(0, 0.6), (1, 0.37), (2, 0.03)]
# 56 [('politics', 0.3772280623994024), ('science', 0.6227719376005976)]
# 56 [(0, 0.31), (2, 0.69)]
# 57 [('sports', 0.3833037089666032), ('politics', 0.6166962910333968)]
# 57 [(0, 0.61), (1, 0.38), (2, 0.01)]
# 58 [('sports', 0.16290487224281597), ('science', 0.8370951277571841)]
# 58 [(1, 0.11), (2, 0.89)]
# 59 [('sports', 0.8913806251404192), ('science', 0.10861937485958084)]
# 59 [(1, 0.92), (2, 0.08)]
# 60 [('science', 0.5793149654406872), ('sports', 0.42068503455931283)]
# 60 [(1, 0.5), (2, 0.5)]
# 61 [('science', 0.44018345970880807), ('politics', 0.5598165402911919)]
# 61 [(0, 0.58), (2, 0.42)]
# 62 [('politics', 0.4993944703482724), ('science', 0.5006055296517277)]
# 62 [(0, 0.55), (2, 0.45)]
# 63 [('sports', 0.3130061162333241), ('politics', 0.6869938837666759)]
# 63 [(0, 0.65), (1, 0.34), (2, 0.01)]
# 64 [('sports', 0.6586609092129182), ('science', 0.34133909078708186)]
# 64 [(1, 0.61), (2, 0.39)]
# 65 [('politics', 0.5232551160560007), ('science', 0.4767448839439992)]
# 65 [(0, 0.51), (2, 0.49)]
# 66 [('sports', 0.06310077966868345), ('science', 0.9368992203313166)]
# 66 [(1, 0.06), (2, 0.94)]
# 67 [('politics', 0.8528595852800448), ('sports', 0.1471404147199552)]
# 67 [(0, 0.89), (1, 0.1), (2, 0.01)]
# 68 [('science', 0.6238773059715202), ('politics', 0.37612269402847975)]
# 68 [(0, 0.51), (2, 0.49)]
# 69 [('politics', 0.8738002652112172), ('science', 0.12619973478878277)]
# 69 [(0, 0.88), (1, 0.01), (2, 0.11)]
# 70 [('sports', 0.66929895941906), ('politics', 0.3307010405809399)]
# 70 [(0, 0.33), (1, 0.67)]
# 71 [('sports', 0.4812088220119836), ('politics', 0.5187911779880164)]
# 71 [(0, 0.5), (1, 0.5)]
# 72 [('science', 0.41840019269754103), ('sports', 0.581599807302459)]
# 72 [(1, 0.58), (2, 0.42)]
# 73 [('science', 0.34686392748248746), ('sports', 0.6531360725175125)]
# 73 [(1, 0.55), (2, 0.45)]
# 74 [('sports', 0.18220008598697995), ('politics', 0.81779991401302)]
# 74 [(0, 0.83), (1, 0.17)]
# 75 [('politics', 0.9638557367153974), ('sports', 0.03614426328460261)]
# 75 [(0, 0.98), (1, 0.02)]
# 76 [('sports', 0.49927146434553193), ('politics', 0.5007285356544681)]
# 76 [(0, 0.43), (1, 0.57)]
# 77 [('politics', 0.3416459475508368), ('sports', 0.6583540524491631)]
# 77 [(0, 0.31), (1, 0.69)]
# 78 [('politics', 0.3634760626190225), ('sports', 0.6365239373809776)]
# 78 [(0, 0.32), (1, 0.68)]
# 79 [('sports', 0.2669655322794313), ('science', 0.7330344677205688)]
# 79 [(1, 0.33), (2, 0.67)]
# 80 [('science', 0.4533985801449402), ('politics', 0.5466014198550597)]
# 80 [(0, 0.48), (1, 0.01), (2, 0.51)]
# 81 [('politics', 0.3872920857994844), ('science', 0.6127079142005156)]
# 81 [(0, 0.36), (2, 0.64)]
# 82 [('science', 0.5439591751113056), ('sports', 0.45604082488869446)]
# 82 [(0, 0.01), (1, 0.4), (2, 0.59)]
# 83 [('sports', 0.8942442360359532), ('politics', 0.10575576396404686)]
# 83 [(0, 0.1), (1, 0.89), (2, 0.01)]
# 84 [('politics', 0.7192449022825467), ('sports', 0.28075509771745333)]
# 84 [(0, 0.76), (1, 0.24)]
# 85 [('sports', 0.4446394199428433), ('science', 0.5553605800571568)]
# 85 [(0, 0.01), (1, 0.5), (2, 0.49)]
# 86 [('sports', 0.8435603193760458), ('politics', 0.15643968062395422)]
# 86 [(0, 0.12), (1, 0.88)]
# 87 [('sports', 0.6138381362132139), ('politics', 0.3861618637867861)]
# 87 [(0, 0.37), (1, 0.62), (2, 0.01)]
# 88 [('sports', 0.37835033341268043), ('politics', 0.6216496665873196)]
# 88 [(0, 0.62), (1, 0.37), (2, 0.01)]
# 89 [('politics', 0.10605084045600463), ('science', 0.8939491595439953)]
# 89 [(0, 0.13), (1, 0.01), (2, 0.86)]
# 90 [('politics', 0.31971293675040124), ('science', 0.6802870632495988)]
# 90 [(0, 0.27), (2, 0.73)]
# 91 [('sports', 0.9731373446545435), ('politics', 0.02686265534545648)]
# 91 [(0, 0.02), (1, 0.98)]
# 92 [('science', 0.4380061848562769), ('politics', 0.5619938151437232)]
# 92 [(0, 0.43), (2, 0.57)]
# 93 [('science', 0.25968270180936853), ('sports', 0.7403172981906314)]
# 93 [(0, 0.01), (1, 0.77), (2, 0.22)]
# 94 [('sports', 0.5219504617082176), ('politics', 0.4780495382917825)]
# 94 [(0, 0.44), (1, 0.56)]
# 95 [('sports', 0.1683915791061135), ('politics', 0.8316084208938866)]
# 95 [(0, 0.8), (1, 0.19), (2, 0.01)]
# 96 [('sports', 0.5382945071050944), ('politics', 0.4617054928949055)]
# 96 [(0, 0.4), (1, 0.6)]
# 97 [('politics', 0.8283366002458811), ('science', 0.1716633997541189)]
# 97 [(0, 0.82), (2, 0.18)]
# 98 [('sports', 0.5750825524210346), ('politics', 0.42491744757896555)]
# 98 [(0, 0.5), (1, 0.5)]
# 99 [('politics', 0.9909240188039051), ('science', 0.009075981196094821)]
# 99 [(0, 0.99), (2, 0.01)]

# %% [markdown]
# ## OK, this works but it needs a speed up: vectorize

# %%
test_docs = [
    {'id': 0, 'words': ['A', 'AA']},
    {'id': 1, 'words': ['B', 'BB']},
    {'id': 2, 'words': ['C', 'CC']},
]
words_idx = ['A', 'AA', 'B', 'BB', 'C', 'CC']
nwords = len(words_idx)
ndocs = len(test_docs)
ntopics = 3
beta = 0.01
alpha = 0.5

random_assignment(test_docs, ntopics=ntopics)

W = words_vs_topics_matrix(test_docs, words_idx, ntopics=ntopics)
D = docs_vs_topics_matrix(test_docs, ntopics=ntopics)

print('W=\n', W)
print('D=\n', D)
# Out:
# W=
#  [[1. 0. 0.]
#  [0. 1. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
# D=
#  [[1. 1. 0.]
#  [1. 1. 0.]
#  [1. 0. 1.]]

# %%
# sum W[:, t]  (por columnas)
np.sum(W, axis=0)
# Out:
# array([3., 2., 1.])

# %%
# sum D[d, :] (por filas)
np.sum(D, axis=1).reshape((ndocs,1))
# Out:
# array([[2.],
#        [2.],
#        [2.]])

# %%
# (W[w,t] + beta) / (sum(W[:,t]) + beta*nwords) matriz W con cada valor normalizado con la suma de la columna
Wnorm = (W + beta) / (np.sum(W, axis=0) + beta*nwords)
Wnorm
# Out:
# array([[0.33006536, 0.00485437, 0.00943396],
#        [0.00326797, 0.49029126, 0.00943396],
#        [0.33006536, 0.00485437, 0.00943396],
#        [0.00326797, 0.49029126, 0.00943396],
#        [0.00326797, 0.00485437, 0.95283019],
#        [0.33006536, 0.00485437, 0.00943396]])

# %%
# (D[d,t] + alpha) / (sum(D[d,:]) + alpha*ntopics)  matriz D con cada valor normalizadp con la suma de la fila
Dnorm = (D + alpha) / (np.sum(D, axis=1).reshape((ndocs,1)) + alpha*ntopics) 
Dnorm
# Out:
# array([[0.42857143, 0.42857143, 0.14285714],
#        [0.42857143, 0.42857143, 0.14285714],
#        [0.42857143, 0.14285714, 0.42857143]])

# %%
# Ahora hay que "combinar" ambas matrices W-norm y D-norm de una manera especial: 
# ambas matrices tienen el mismo número de columnas, una por topic. Cada columna j de la matriz W-norm se tiene 
# que combinar con la misma columna j de la matriz D-norm (mismo topic). 
# Combinar: por cada elemento de la columna de W-norm multiplicarlo por cada elemento de la columna 
# de D-norm, generando en total nwords*ndocs elementos. Esto se consige "expandiendo" una de las columnas 
# tantas veces como elementos tiene la otra y luego multiplicando. 
# con esto conseguimos una matriz P[nwords, ndocs, ntopics]

# %%
P = np.stack([Dnorm]*Wnorm.shape[0], axis=1) * Wnorm
P
# Out:
# array([[[0.14145658, 0.00208044, 0.00134771],
#         [0.00140056, 0.21012483, 0.00134771],
#         [0.14145658, 0.00208044, 0.00134771],
#         [0.00140056, 0.21012483, 0.00134771],
#         [0.00140056, 0.00208044, 0.1361186 ],
#         [0.14145658, 0.00208044, 0.00134771]],
#
#        [[0.14145658, 0.00208044, 0.00134771],
#         [0.00140056, 0.21012483, 0.00134771],
#         [0.14145658, 0.00208044, 0.00134771],
#         [0.00140056, 0.21012483, 0.00134771],
#         [0.00140056, 0.00208044, 0.1361186 ],
#         [0.14145658, 0.00208044, 0.00134771]],
#
#        [[0.14145658, 0.00069348, 0.00404313],
#         [0.00140056, 0.07004161, 0.00404313],
#         [0.14145658, 0.00069348, 0.00404313],
#         [0.00140056, 0.07004161, 0.00404313],
#         [0.00140056, 0.00069348, 0.4083558 ],
#         [0.14145658, 0.00069348, 0.00404313]]])

# %%
P[1,5,1]
# Out:
# 0.002080443828016643

# %%
# primero normalizamos la matriz P para que se convierta en una matriz de probabilidades (filas sumen 1)
Pnorm = P/np.sum(P, axis=2).reshape((ndocs, nwords, 1))
Pnorm
# Out:
# array([[[0.97633876, 0.0143593 , 0.00930194],
#         [0.00657932, 0.98708964, 0.00633104],
#         [0.97633876, 0.0143593 , 0.00930194],
#         [0.00657932, 0.98708964, 0.00633104],
#         [0.01003269, 0.01490294, 0.97506437],
#         [0.97633876, 0.0143593 , 0.00930194]],
#
#        [[0.97633876, 0.0143593 , 0.00930194],
#         [0.00657932, 0.98708964, 0.00633104],
#         [0.97633876, 0.0143593 , 0.00930194],
#         [0.00657932, 0.98708964, 0.00633104],
#         [0.01003269, 0.01490294, 0.97506437],
#         [0.97633876, 0.0143593 , 0.00930194]],
#
#        [[0.96760035, 0.00474359, 0.02765605],
#         [0.01855408, 0.92788414, 0.05356178],
#         [0.96760035, 0.00474359, 0.02765605],
#         [0.01855408, 0.92788414, 0.05356178],
#         [0.00341226, 0.00168956, 0.99489818],
#         [0.96760035, 0.00474359, 0.02765605]]])

# %% [markdown]
# ## Problema
#
# Pnorm nos permite seleccionar aleatoriamente el nuevo topic para cada palabra de cada documento. El problema que tenemos es que si un documento contiene la misma palabra más de una vez, la representacion "bag of words" que estábamos usando no nos sirve, cada ocurrencia de la misma palabra deberíamos tratarla por separado (pueden venir de distintos topics). Esto complica el trabajar con matrices, ya que la alternativa es representar un documento como una lista de longitud variable de vectores "one hot encoding" (un vector por palabra).
#
# -- Representación "Bag of Words":
# DW = [[2,0,1], # el doc 0 contiene dos veces la palabra 0 y 1 vez la palabra 2
#       [0,2,0], # el doc 1 contiene dos veces la palabra 1
#       [1,1,0]] # ...
#
# -- Representación one hot encoding de la misma matriz
# DWb = [[[1,0,0], [1,0,0], [0,0,1]],  # dos vectores distintos para las dos ocurrencias de la palabra 0
#        [[0,1,0], [0,1,0]],
#        [[1,0,0], [1,0,0]]
#       ]
#
#
# Podemos seguir de dos/tres formas:
#
# 0. Continuar con la representación "bag of words" y asumir que el algoritmo puede no converger bien.
#
# 1. Versión secuencial: iterar para cada documento d, para cada palabra w. Pnorm[d][w] contiene el vector de probabilidades para seleccionar el nuevo topic. O(ndocs * nwordsmedio * O(random.choice(ntopics)) )
#
# 2. Versión matricial con sparse matrix: el problema aquí es que cada documento tiene longitud variable de palabras. La solucion bestia: calcular el documento más largo y completar el resto con vectores vacíos. Esto obliga en la práctica a usar sparse matrices.

# %% [markdown]
# ## Opción 0
#
# Si tengo 5 ocurrencias de la misma palabra en un documento, selecciono el mismo nuevo topic para todas ellas.
#
# Para vectorizar la seleccion aleatoria del nuevo topic (para cada palabra de cada documento) se necesita una función random.choice() en paralelo
#
# https://stackoverflow.com/a/57238866

# %%
# generamos la suma cumulativa por filas
Pnormcum = Pnorm.cumsum(axis=2)
Pnormcum
# Out:
# array([[[0.97633876, 0.99069806, 1.        ],
#         [0.00657932, 0.99366896, 1.        ],
#         [0.97633876, 0.99069806, 1.        ],
#         [0.00657932, 0.99366896, 1.        ],
#         [0.01003269, 0.02493563, 1.        ],
#         [0.97633876, 0.99069806, 1.        ]],
#
#        [[0.97633876, 0.99069806, 1.        ],
#         [0.00657932, 0.99366896, 1.        ],
#         [0.97633876, 0.99069806, 1.        ],
#         [0.00657932, 0.99366896, 1.        ],
#         [0.01003269, 0.02493563, 1.        ],
#         [0.97633876, 0.99069806, 1.        ]],
#
#        [[0.96760035, 0.97234395, 1.        ],
#         [0.01855408, 0.94643822, 1.        ],
#         [0.96760035, 0.97234395, 1.        ],
#         [0.01855408, 0.94643822, 1.        ],
#         [0.00341226, 0.00510182, 1.        ],
#         [0.96760035, 0.97234395, 1.        ]]])

# %%
# para cada una de las filas generamos un numero aleatorio entre 0 y 1
r = np.random.rand(Pnorm.shape[0], Pnorm.shape[1], 1)
r
# Out:
# array([[[0.1698489 ],
#         [0.46895872],
#         [0.93194399],
#         [0.31099902],
#         [0.41632183],
#         [0.15577227]],
#
#        [[0.69572806],
#         [0.46911913],
#         [0.93911042],
#         [0.25447041],
#         [0.21976453],
#         [0.79874256]],
#
#        [[0.74613682],
#         [0.21550664],
#         [0.60849858],
#         [0.37751744],
#         [0.65856802],
#         [0.41614583]]])

# %%
# y ahora el truco que me encanta
q = Pnormcum >= r
q
# Out:
# array([[[ True,  True,  True],
#         [False,  True,  True],
#         [ True,  True,  True],
#         [False,  True,  True],
#         [False, False,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [False,  True,  True],
#         [ True,  True,  True],
#         [False,  True,  True],
#         [False, False,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [False,  True,  True],
#         [ True,  True,  True],
#         [False,  True,  True],
#         [False, False,  True],
#         [ True,  True,  True]]])

# %%
Tnew = np.argmax(Pnormcum >= r, axis=-1).reshape((ndocs, nwords, 1))
Tnew
# Out:
# array([[[0],
#         [1],
#         [0],
#         [1],
#         [2],
#         [0]],
#
#        [[0],
#         [1],
#         [0],
#         [1],
#         [2],
#         [0]],
#
#        [[0],
#         [1],
#         [0],
#         [1],
#         [2],
#         [0]]])

# %%
# en realidad sin el reshape queda mejor. Tnew[nwords, ndocs]:
Tnew = np.argmax(Pnormcum >= r, axis=-1)

d = 0  # document 0
w = 0  # word 0
Tnew[d,w]
# Out:
# 0

# %%
# ahora falta actualizar las matrices W y D
Tnew
# Out:
# array([[0, 1, 0, 1, 2, 0],
#        [0, 1, 0, 1, 2, 0],
#        [0, 1, 0, 1, 2, 0]])

# %% [markdown]
# ## Opción 1
#
# Versión secuencial

# %% [markdown]
# ## Opción 2
#
# Sparse matrices
