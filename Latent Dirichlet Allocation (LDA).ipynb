# %% [markdown]
# ## LATENT DIRICHLET ALLOCATION
#
# https://medium.com/@lettier/how-does-lda-work-ill-explain-using-emoji-108abf40fa7d
#
# https://www.youtube.com/watch?v=DWJYZq_fQ2A

# %%
import random
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np

topic1 = {
    'id': 'sports', 
    'words': ['football', 'basketball', 'gol', 'play', 'match', 'space'],
    'weights': [4, 1, 1, 1, 1, 2]
}
topic2 = {
    'id': 'politics', 
    'words': ['president', 'interview', 'twitter', 'television', 'debate', 'space'],
    'weights': [2, 1, 4, 1, 1, 1]
}
topic3 = {
    'id': 'science', 
    'words': ['science', 'molecula', 'debate', 'space'],
    'weights': [1, 1, 1, 1]
}

topics = [topic1, topic2, topic3]


# topic1 = {
#     'id': 'sports', 
#     'words': ['football', 'basketball', 'match'],
#     'weights': [1,1,1]
# }
# topic2 = {
#     'id': 'politics', 
#     'words': ['president', 'interview', 'twitter'],
#     'weights': [1, 1, 1]
# }
# topic3 = {
#     'id': 'science', 
#     'words': ['science', 'molecula', 'space'],
#     'weights': [1, 1, 1]
# }

topics = [topic1, topic2, topic3]


# topic1 = {
#     'id': 'dogs', 
#     'words': ['guau', 'guau2'],
#     'weights': [1, 1]
# }
# topic2 = {
#     'id': 'cats', 
#     'words': ['miaw', 'miaw2'],
#     'weights': [1, 1]
# }

# topics = [topic1, topic2]

# %%
def generate_documents(topics, num_docs=100, topics_per_doc=2, words_per_doc=1000):
    documents = []
    for i in range(num_docs):
        # first select several topics
        doc_topics = random.sample(topics, topics_per_doc)

        # asign a weight to each topic of the document
        r = [random.random() for _ in range(0, topics_per_doc)]
        s = sum(r)
        doc_topics_weights = [ i/s for i in r ]
        
        # now sample the topics to generate the document. 
        # NOTE: this is an inefficient version for teaching purposes
        doc_words = [] 
        for _ in range(words_per_doc):
            topic = random.choices(doc_topics, doc_topics_weights)[0]  # select one topic
            doc_words = doc_words + random.choices(topic['words'], topic['weights'], k=1)  # choose one word
        
        documents.append({'id': i, 'words': doc_words, 'topics_weights': [(t[0]['id'], t[1]) for t in zip(doc_topics, doc_topics_weights)]})
        
        words_idx = list(set([word for doc in documents for word in doc['words']]))
        docs_idx = [doc['id'] for doc in documents]
    return documents, docs_idx, words_idx


docs, docs_idx, words_idx = generate_documents(topics, num_docs=100, topics_per_doc=2, words_per_doc=100)
docs
# Out:
# [{'id': 0,
#   'words': ['basketball',
#    'basketball',
#    'football',
#    'molecula',
#    'match',
#    'molecula',
#    'football',
#    'football',
#    'debate',
#    'play',
#    'debate',
#    'basketball',
#    'science',
#    'play',
#    'play',
#    'space',
#    'space',
#    'match',
#    'match',
#    'football',
#    'play',
#    'football',
#    'science',
#    'basketball',
#    'match',
#    'play',
#    'gol',
#    'football',
#    'basketball',
#    'football',
#    'debate',
#    'debate',
#    'space',
#    'space',
#    'football',
#    'space',
#    'football',
#    'football',
#    'football',
#    'football',
#    'debate',
#    'football',
#    'gol',
#    'space',
#    'debate',
#    'play',
#    'play',
#    'football',
#    'science',
#    'play',
#    'football',
#    'space',
#    'football',
#    'space',
#    'gol',
#    'football',
#    'football',
#    'basketball',
#    'space',
#    'basketball',
#    'football',
#    'debate',
#    'debate',
#    'play',
#    'space',
#    'space',
#    'football',
#    'debate',
#    'football',
#    'debate',
#    'gol',
#    'space',
#    'football',
#    'space',
#    'space',
#    'science',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'space',
#    'football',
#    'gol',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'science',
#    'football',
#    'football',
#    'space',
#    'space',
#    'play',
#    'match',
#    'debate',
#    'gol',
#    'football',
#    'molecula',
#    'match',
#    'play'],
#   'topics_weights': [('science', 0.24456755248379008),
#    ('sports', 0.75543244751621)]},
#  {'id': 1,
#   'words': ['football',
#    'interview',
#    'interview',
#    'twitter',
#    'football',
#    'gol',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'basketball',
#    'space',
#    'football',
#    'twitter',
#    'interview',
#    'president',
#    'football',
#    'twitter',
#    'television',
#    'football',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'television',
#    'space',
#    'twitter',
#    'president',
#    'television',
#    'football',
#    'match',
#    'space',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'space',
#    'football',
#    'television',
#    'president',
#    'space',
#    'interview',
#    'interview',
#    'debate',
#    'television',
#    'space',
#    'twitter',
#    'debate',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'gol',
#    'basketball',
#    'play',
#    'president',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'debate',
#    'football',
#    'football',
#    'space',
#    'debate',
#    'president',
#    'gol',
#    'football',
#    'president',
#    'space',
#    'president',
#    'space',
#    'match',
#    'football',
#    'interview',
#    'football',
#    'football',
#    'twitter',
#    'debate',
#    'debate',
#    'president',
#    'debate',
#    'football',
#    'twitter',
#    'debate',
#    'twitter',
#    'play',
#    'president',
#    'football',
#    'interview'],
#   'topics_weights': [('sports', 0.35727722282000307),
#    ('politics', 0.6427227771799969)]},
#  {'id': 2,
#   'words': ['gol',
#    'football',
#    'play',
#    'space',
#    'football',
#    'gol',
#    'debate',
#    'football',
#    'science',
#    'football',
#    'gol',
#    'debate',
#    'space',
#    'space',
#    'play',
#    'space',
#    'basketball',
#    'molecula',
#    'football',
#    'gol',
#    'molecula',
#    'science',
#    'football',
#    'debate',
#    'molecula',
#    'molecula',
#    'space',
#    'science',
#    'debate',
#    'football',
#    'debate',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'football',
#    'science',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'science',
#    'debate',
#    'gol',
#    'football',
#    'play',
#    'play',
#    'gol',
#    'football',
#    'debate',
#    'football',
#    'football',
#    'match',
#    'football',
#    'molecula',
#    'basketball',
#    'football',
#    'molecula',
#    'science',
#    'football',
#    'molecula',
#    'basketball',
#    'space',
#    'molecula',
#    'molecula',
#    'play',
#    'debate',
#    'football',
#    'debate',
#    'football',
#    'space',
#    'match',
#    'science',
#    'basketball',
#    'match',
#    'football',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'football',
#    'space',
#    'space',
#    'gol',
#    'molecula',
#    'space',
#    'debate',
#    'play',
#    'molecula',
#    'gol',
#    'football',
#    'molecula',
#    'basketball',
#    'football',
#    'debate',
#    'science',
#    'science',
#    'football',
#    'space',
#    'space'],
#   'topics_weights': [('sports', 0.542989916612604),
#    ('science', 0.45701008338739607)]},
#  {'id': 3,
#   'words': ['debate',
#    'football',
#    'debate',
#    'space',
#    'science',
#    'football',
#    'debate',
#    'basketball',
#    'molecula',
#    'space',
#    'football',
#    'science',
#    'gol',
#    'basketball',
#    'football',
#    'football',
#    'space',
#    'football',
#    'molecula',
#    'space',
#    'debate',
#    'football',
#    'molecula',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'science',
#    'basketball',
#    'football',
#    'science',
#    'football',
#    'gol',
#    'space',
#    'football',
#    'molecula',
#    'play',
#    'space',
#    'science',
#    'football',
#    'football',
#    'football',
#    'space',
#    'gol',
#    'football',
#    'play',
#    'space',
#    'science',
#    'basketball',
#    'space',
#    'molecula',
#    'molecula',
#    'football',
#    'space',
#    'basketball',
#    'football',
#    'football',
#    'science',
#    'match',
#    'debate',
#    'space',
#    'molecula',
#    'play',
#    'football',
#    'match',
#    'play',
#    'basketball',
#    'football',
#    'space',
#    'space',
#    'basketball',
#    'football',
#    'space',
#    'play',
#    'debate',
#    'science',
#    'football',
#    'space',
#    'football',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'basketball',
#    'molecula',
#    'play',
#    'space',
#    'debate',
#    'space',
#    'gol',
#    'science',
#    'football',
#    'debate',
#    'football',
#    'play',
#    'space',
#    'play',
#    'debate',
#    'molecula',
#    'football'],
#   'topics_weights': [('science', 0.39538758109917665),
#    ('sports', 0.6046124189008233)]},
#  {'id': 4,
#   'words': ['gol',
#    'match',
#    'football',
#    'space',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'basketball',
#    'match',
#    'football',
#    'space',
#    'play',
#    'space',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'match',
#    'football',
#    'molecula',
#    'football',
#    'space',
#    'football',
#    'basketball',
#    'basketball',
#    'football',
#    'play',
#    'football',
#    'space',
#    'play',
#    'space',
#    'match',
#    'football',
#    'football',
#    'gol',
#    'space',
#    'football',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'space',
#    'match',
#    'football',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'football',
#    'play',
#    'space',
#    'match',
#    'match',
#    'space',
#    'basketball',
#    'football',
#    'gol',
#    'basketball',
#    'space',
#    'gol',
#    'football',
#    'gol',
#    'football',
#    'gol',
#    'basketball',
#    'space',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'football',
#    'molecula',
#    'space',
#    'football',
#    'football',
#    'gol',
#    'match',
#    'basketball',
#    'football',
#    'basketball',
#    'basketball',
#    'football',
#    'basketball',
#    'play',
#    'space',
#    'football',
#    'space',
#    'space',
#    'football',
#    'football',
#    'play',
#    'football',
#    'space',
#    'basketball',
#    'gol',
#    'space'],
#   'topics_weights': [('science', 0.07236994958194534),
#    ('sports', 0.9276300504180547)]},
#  {'id': 5,
#   'words': ['twitter',
#    'twitter',
#    'debate',
#    'match',
#    'president',
#    'twitter',
#    'president',
#    'football',
#    'football',
#    'gol',
#    'president',
#    'space',
#    'play',
#    'president',
#    'twitter',
#    'twitter',
#    'television',
#    'football',
#    'president',
#    'space',
#    'president',
#    'match',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'football',
#    'debate',
#    'twitter',
#    'television',
#    'basketball',
#    'football',
#    'match',
#    'twitter',
#    'television',
#    'president',
#    'play',
#    'football',
#    'space',
#    'football',
#    'basketball',
#    'match',
#    'twitter',
#    'football',
#    'television',
#    'gol',
#    'twitter',
#    'president',
#    'football',
#    'space',
#    'president',
#    'president',
#    'interview',
#    'twitter',
#    'interview',
#    'play',
#    'football',
#    'television',
#    'twitter',
#    'basketball',
#    'debate',
#    'twitter',
#    'twitter',
#    'television',
#    'twitter',
#    'basketball',
#    'football',
#    'debate',
#    'football',
#    'basketball',
#    'gol',
#    'twitter',
#    'football',
#    'match',
#    'football',
#    'gol',
#    'television',
#    'space',
#    'twitter',
#    'television',
#    'space',
#    'debate',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'television',
#    'twitter',
#    'space',
#    'twitter',
#    'match',
#    'match',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'gol',
#    'space',
#    'play'],
#   'topics_weights': [('sports', 0.43887033509303514),
#    ('politics', 0.5611296649069649)]},
#  {'id': 6,
#   'words': ['twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'debate',
#    'twitter',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'interview',
#    'gol',
#    'space',
#    'space',
#    'president',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'space',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'interview',
#    'twitter',
#    'twitter',
#    'debate',
#    'president',
#    'twitter',
#    'space',
#    'twitter',
#    'television',
#    'space',
#    'space',
#    'television',
#    'president',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'space',
#    'president',
#    'space',
#    'television',
#    'football',
#    'twitter',
#    'interview',
#    'space',
#    'gol',
#    'television',
#    'television',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'president',
#    'space',
#    'interview',
#    'president',
#    'twitter',
#    'football',
#    'president',
#    'twitter',
#    'interview',
#    'president',
#    'interview',
#    'twitter',
#    'twitter',
#    'president',
#    'interview',
#    'television',
#    'interview',
#    'president',
#    'space',
#    'debate',
#    'play',
#    'television',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'president',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'interview',
#    'debate',
#    'television',
#    'president',
#    'television'],
#   'topics_weights': [('sports', 0.11407328212216619),
#    ('politics', 0.8859267178778338)]},
#  {'id': 7,
#   'words': ['space',
#    'debate',
#    'science',
#    'debate',
#    'play',
#    'debate',
#    'molecula',
#    'basketball',
#    'football',
#    'science',
#    'play',
#    'football',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'football',
#    'debate',
#    'gol',
#    'science',
#    'space',
#    'football',
#    'debate',
#    'molecula',
#    'play',
#    'space',
#    'football',
#    'match',
#    'space',
#    'space',
#    'space',
#    'space',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'gol',
#    'debate',
#    'molecula',
#    'match',
#    'debate',
#    'space',
#    'football',
#    'play',
#    'space',
#    'science',
#    'debate',
#    'play',
#    'play',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'debate',
#    'space',
#    'science',
#    'football',
#    'science',
#    'science',
#    'basketball',
#    'molecula',
#    'debate',
#    'space',
#    'gol',
#    'science',
#    'debate',
#    'football',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'football',
#    'space',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'space',
#    'football',
#    'space',
#    'space',
#    'science',
#    'molecula',
#    'football',
#    'molecula',
#    'molecula',
#    'molecula',
#    'football',
#    'space',
#    'science',
#    'debate',
#    'play',
#    'molecula',
#    'space',
#    'science'],
#   'topics_weights': [('science', 0.6406622574014711),
#    ('sports', 0.3593377425985289)]},
#  {'id': 8,
#   'words': ['match',
#    'space',
#    'football',
#    'football',
#    'football',
#    'science',
#    'football',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'space',
#    'match',
#    'match',
#    'space',
#    'football',
#    'play',
#    'football',
#    'match',
#    'gol',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'match',
#    'gol',
#    'gol',
#    'football',
#    'space',
#    'match',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'basketball',
#    'space',
#    'space',
#    'football',
#    'space',
#    'gol',
#    'molecula',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'space',
#    'space',
#    'space',
#    'space',
#    'space',
#    'gol',
#    'space',
#    'play',
#    'space',
#    'debate',
#    'basketball',
#    'basketball',
#    'football',
#    'football',
#    'play',
#    'basketball',
#    'match',
#    'basketball',
#    'basketball',
#    'football',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'football',
#    'debate',
#    'space',
#    'gol',
#    'space',
#    'match',
#    'gol',
#    'football',
#    'debate',
#    'football',
#    'football',
#    'play',
#    'space',
#    'basketball',
#    'space',
#    'gol',
#    'space',
#    'play',
#    'match',
#    'football',
#    'match'],
#   'topics_weights': [('science', 0.09343523903964185),
#    ('sports', 0.9065647609603581)]},
#  {'id': 9,
#   'words': ['match',
#    'play',
#    'gol',
#    'space',
#    'molecula',
#    'space',
#    'science',
#    'molecula',
#    'football',
#    'molecula',
#    'space',
#    'molecula',
#    'gol',
#    'space',
#    'molecula',
#    'molecula',
#    'match',
#    'gol',
#    'debate',
#    'molecula',
#    'match',
#    'basketball',
#    'space',
#    'molecula',
#    'football',
#    'space',
#    'molecula',
#    'molecula',
#    'football',
#    'football',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'science',
#    'debate',
#    'science',
#    'science',
#    'football',
#    'basketball',
#    'space',
#    'debate',
#    'football',
#    'molecula',
#    'football',
#    'molecula',
#    'debate',
#    'football',
#    'debate',
#    'space',
#    'football',
#    'debate',
#    'debate',
#    'match',
#    'space',
#    'space',
#    'space',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'gol',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'gol',
#    'gol',
#    'football',
#    'science',
#    'science',
#    'debate',
#    'play',
#    'space',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'debate',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'gol',
#    'molecula'],
#   'topics_weights': [('sports', 0.4143566061847329),
#    ('science', 0.5856433938152672)]},
#  {'id': 10,
#   'words': ['space',
#    'science',
#    'interview',
#    'interview',
#    'television',
#    'molecula',
#    'science',
#    'debate',
#    'twitter',
#    'molecula',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'space',
#    'science',
#    'television',
#    'space',
#    'debate',
#    'television',
#    'president',
#    'debate',
#    'molecula',
#    'interview',
#    'debate',
#    'science',
#    'television',
#    'president',
#    'debate',
#    'president',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'twitter',
#    'molecula',
#    'molecula',
#    'debate',
#    'twitter',
#    'television',
#    'debate',
#    'science',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'debate',
#    'debate',
#    'debate',
#    'president',
#    'debate',
#    'debate',
#    'molecula',
#    'twitter',
#    'twitter',
#    'space',
#    'science',
#    'space',
#    'interview',
#    'molecula',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'president',
#    'interview',
#    'science',
#    'molecula',
#    'twitter',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'science',
#    'science',
#    'debate',
#    'space',
#    'interview',
#    'twitter',
#    'interview',
#    'debate'],
#   'topics_weights': [('science', 0.5936265713383261),
#    ('politics', 0.40637342866167403)]},
#  {'id': 11,
#   'words': ['twitter',
#    'president',
#    'space',
#    'play',
#    'twitter',
#    'space',
#    'play',
#    'twitter',
#    'president',
#    'football',
#    'space',
#    'match',
#    'gol',
#    'football',
#    'television',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'television',
#    'television',
#    'twitter',
#    'match',
#    'space',
#    'play',
#    'football',
#    'twitter',
#    'interview',
#    'space',
#    'space',
#    'president',
#    'football',
#    'gol',
#    'president',
#    'television',
#    'twitter',
#    'basketball',
#    'match',
#    'football',
#    'president',
#    'football',
#    'space',
#    'interview',
#    'football',
#    'space',
#    'football',
#    'president',
#    'debate',
#    'football',
#    'president',
#    'debate',
#    'space',
#    'president',
#    'play',
#    'play',
#    'space',
#    'space',
#    'twitter',
#    'president',
#    'gol',
#    'president',
#    'gol',
#    'basketball',
#    'space',
#    'space',
#    'debate',
#    'football',
#    'president',
#    'football',
#    'play',
#    'twitter',
#    'president',
#    'twitter',
#    'gol',
#    'play',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'television',
#    'football',
#    'play',
#    'basketball',
#    'twitter',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'twitter',
#    'twitter',
#    'interview',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'football',
#    'twitter'],
#   'topics_weights': [('politics', 0.5305417543340212),
#    ('sports', 0.46945824566597877)]},
#  {'id': 12,
#   'words': ['football',
#    'science',
#    'football',
#    'football',
#    'science',
#    'debate',
#    'debate',
#    'molecula',
#    'science',
#    'match',
#    'football',
#    'molecula',
#    'space',
#    'debate',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'science',
#    'football',
#    'space',
#    'match',
#    'science',
#    'space',
#    'basketball',
#    'science',
#    'space',
#    'science',
#    'science',
#    'basketball',
#    'football',
#    'space',
#    'space',
#    'science',
#    'space',
#    'space',
#    'science',
#    'football',
#    'space',
#    'play',
#    'molecula',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'science',
#    'space',
#    'space',
#    'space',
#    'match',
#    'space',
#    'debate',
#    'molecula',
#    'basketball',
#    'football',
#    'space',
#    'gol',
#    'science',
#    'space',
#    'match',
#    'football',
#    'basketball',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'football',
#    'molecula',
#    'molecula',
#    'debate',
#    'molecula',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'basketball',
#    'space',
#    'football',
#    'science',
#    'space',
#    'gol',
#    'molecula',
#    'space',
#    'molecula',
#    'debate',
#    'play',
#    'football',
#    'space',
#    'science',
#    'space',
#    'gol',
#    'debate',
#    'space',
#    'debate',
#    'match',
#    'space',
#    'football',
#    'science',
#    'match',
#    'football'],
#   'topics_weights': [('sports', 0.415927780693171),
#    ('science', 0.584072219306829)]},
#  {'id': 13,
#   'words': ['space',
#    'twitter',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'molecula',
#    'science',
#    'twitter',
#    'space',
#    'debate',
#    'science',
#    'science',
#    'president',
#    'molecula',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'molecula',
#    'science',
#    'science',
#    'molecula',
#    'space',
#    'twitter',
#    'space',
#    'science',
#    'debate',
#    'twitter',
#    'twitter',
#    'interview',
#    'twitter',
#    'interview',
#    'debate',
#    'science',
#    'president',
#    'twitter',
#    'president',
#    'president',
#    'twitter',
#    'television',
#    'science',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'twitter',
#    'interview',
#    'molecula',
#    'president',
#    'debate',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'interview',
#    'molecula',
#    'twitter',
#    'space',
#    'science',
#    'molecula',
#    'science',
#    'television',
#    'twitter',
#    'debate',
#    'molecula',
#    'television',
#    'science',
#    'twitter',
#    'president',
#    'space',
#    'twitter',
#    'debate',
#    'science',
#    'president',
#    'molecula',
#    'debate',
#    'science',
#    'debate',
#    'debate',
#    'president',
#    'space',
#    'debate',
#    'twitter',
#    'debate',
#    'president',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'television',
#    'debate',
#    'debate',
#    'television'],
#   'topics_weights': [('science', 0.6011752452866223),
#    ('politics', 0.3988247547133778)]},
#  {'id': 14,
#   'words': ['football',
#    'space',
#    'president',
#    'space',
#    'gol',
#    'president',
#    'president',
#    'space',
#    'space',
#    'play',
#    'president',
#    'twitter',
#    'football',
#    'space',
#    'football',
#    'twitter',
#    'president',
#    'president',
#    'president',
#    'match',
#    'gol',
#    'president',
#    'twitter',
#    'gol',
#    'president',
#    'football',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'gol',
#    'television',
#    'interview',
#    'basketball',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'debate',
#    'space',
#    'football',
#    'president',
#    'twitter',
#    'play',
#    'match',
#    'football',
#    'president',
#    'play',
#    'twitter',
#    'television',
#    'football',
#    'gol',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'space',
#    'play',
#    'match',
#    'space',
#    'space',
#    'play',
#    'television',
#    'match',
#    'twitter',
#    'football',
#    'twitter',
#    'football',
#    'football',
#    'basketball',
#    'basketball',
#    'match',
#    'gol',
#    'space',
#    'twitter',
#    'football',
#    'president',
#    'space',
#    'television',
#    'twitter',
#    'twitter',
#    'interview',
#    'television',
#    'twitter',
#    'president',
#    'space',
#    'interview',
#    'football',
#    'play',
#    'match',
#    'space',
#    'basketball',
#    'president',
#    'space',
#    'president',
#    'twitter',
#    'gol',
#    'president',
#    'twitter'],
#   'topics_weights': [('sports', 0.6017576169801229),
#    ('politics', 0.39824238301987713)]},
#  {'id': 15,
#   'words': ['gol',
#    'play',
#    'debate',
#    'science',
#    'football',
#    'football',
#    'space',
#    'space',
#    'gol',
#    'football',
#    'space',
#    'basketball',
#    'football',
#    'play',
#    'science',
#    'debate',
#    'match',
#    'match',
#    'gol',
#    'match',
#    'football',
#    'space',
#    'match',
#    'debate',
#    'match',
#    'space',
#    'basketball',
#    'debate',
#    'football',
#    'molecula',
#    'space',
#    'space',
#    'match',
#    'space',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'gol',
#    'football',
#    'space',
#    'gol',
#    'space',
#    'basketball',
#    'football',
#    'basketball',
#    'basketball',
#    'space',
#    'basketball',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'football',
#    'science',
#    'match',
#    'basketball',
#    'football',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'debate',
#    'molecula',
#    'space',
#    'science',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'basketball',
#    'debate',
#    'play',
#    'science',
#    'play',
#    'science',
#    'play',
#    'play',
#    'space',
#    'molecula',
#    'football',
#    'space',
#    'space',
#    'football',
#    'football',
#    'basketball',
#    'space',
#    'basketball',
#    'play',
#    'basketball',
#    'basketball',
#    'match',
#    'space',
#    'space',
#    'play',
#    'space',
#    'football',
#    'football',
#    'football',
#    'debate'],
#   'topics_weights': [('sports', 0.8546393923286264),
#    ('science', 0.1453606076713736)]},
#  {'id': 16,
#   'words': ['science',
#    'space',
#    'football',
#    'space',
#    'space',
#    'molecula',
#    'space',
#    'debate',
#    'match',
#    'science',
#    'match',
#    'space',
#    'football',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'football',
#    'science',
#    'space',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'space',
#    'play',
#    'football',
#    'debate',
#    'football',
#    'science',
#    'debate',
#    'football',
#    'science',
#    'match',
#    'science',
#    'science',
#    'molecula',
#    'match',
#    'debate',
#    'debate',
#    'football',
#    'science',
#    'space',
#    'football',
#    'molecula',
#    'space',
#    'basketball',
#    'debate',
#    'football',
#    'football',
#    'space',
#    'molecula',
#    'basketball',
#    'molecula',
#    'debate',
#    'science',
#    'space',
#    'science',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'match',
#    'debate',
#    'space',
#    'basketball',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'gol',
#    'football',
#    'space',
#    'science',
#    'basketball',
#    'football',
#    'space',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'football',
#    'space',
#    'molecula',
#    'basketball',
#    'match',
#    'science',
#    'space',
#    'play',
#    'football',
#    'football'],
#   'topics_weights': [('science', 0.5514140698624164),
#    ('sports', 0.4485859301375837)]},
#  {'id': 17,
#   'words': ['football',
#    'twitter',
#    'president',
#    'space',
#    'basketball',
#    'twitter',
#    'football',
#    'play',
#    'football',
#    'football',
#    'president',
#    'play',
#    'football',
#    'gol',
#    'football',
#    'gol',
#    'gol',
#    'football',
#    'match',
#    'president',
#    'president',
#    'twitter',
#    'twitter',
#    'television',
#    'space',
#    'basketball',
#    'football',
#    'twitter',
#    'play',
#    'debate',
#    'football',
#    'twitter',
#    'twitter',
#    'twitter',
#    'twitter',
#    'play',
#    'football',
#    'space',
#    'space',
#    'president',
#    'football',
#    'space',
#    'twitter',
#    'play',
#    'basketball',
#    'match',
#    'football',
#    'twitter',
#    'president',
#    'twitter',
#    'interview',
#    'match',
#    'twitter',
#    'space',
#    'football',
#    'play',
#    'space',
#    'football',
#    'match',
#    'basketball',
#    'space',
#    'football',
#    'twitter',
#    'football',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'space',
#    'football',
#    'space',
#    'president',
#    'football',
#    'space',
#    'president',
#    'twitter',
#    'match',
#    'gol',
#    'president',
#    'football',
#    'play',
#    'match',
#    'match',
#    'football',
#    'football',
#    'match',
#    'football',
#    'play',
#    'football',
#    'television',
#    'twitter',
#    'football',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'president'],
#   'topics_weights': [('sports', 0.5966290926432847),
#    ('politics', 0.40337090735671544)]},
#  {'id': 18,
#   'words': ['debate',
#    'debate',
#    'space',
#    'molecula',
#    'interview',
#    'television',
#    'twitter',
#    'debate',
#    'molecula',
#    'science',
#    'debate',
#    'twitter',
#    'molecula',
#    'debate',
#    'space',
#    'twitter',
#    'science',
#    'debate',
#    'twitter',
#    'space',
#    'debate',
#    'television',
#    'interview',
#    'twitter',
#    'molecula',
#    'space',
#    'interview',
#    'debate',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'television',
#    'science',
#    'science',
#    'twitter',
#    'twitter',
#    'space',
#    'molecula',
#    'molecula',
#    'twitter',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'science',
#    'science',
#    'molecula',
#    'interview',
#    'debate',
#    'science',
#    'molecula',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'president',
#    'debate',
#    'twitter',
#    'science',
#    'president',
#    'molecula',
#    'science',
#    'interview',
#    'television',
#    'molecula',
#    'science',
#    'president',
#    'interview',
#    'space',
#    'debate',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'twitter',
#    'twitter',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'television',
#    'debate',
#    'twitter',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'television',
#    'science',
#    'space',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'president'],
#   'topics_weights': [('science', 0.6074891321791508),
#    ('politics', 0.3925108678208492)]},
#  {'id': 19,
#   'words': ['twitter',
#    'president',
#    'space',
#    'twitter',
#    'president',
#    'molecula',
#    'president',
#    'molecula',
#    'twitter',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'president',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'molecula',
#    'space',
#    'television',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'molecula',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'television',
#    'molecula',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'television',
#    'science',
#    'interview',
#    'science',
#    'space',
#    'debate',
#    'molecula',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'debate',
#    'interview',
#    'debate',
#    'space',
#    'television',
#    'debate',
#    'president',
#    'president',
#    'interview',
#    'interview',
#    'twitter',
#    'molecula',
#    'molecula',
#    'television',
#    'president',
#    'debate',
#    'science',
#    'television',
#    'molecula',
#    'science',
#    'space',
#    'debate',
#    'president',
#    'space',
#    'science',
#    'debate',
#    'twitter',
#    'twitter',
#    'space',
#    'space',
#    'space',
#    'president',
#    'space',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'debate',
#    'twitter',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'television',
#    'interview',
#    'molecula',
#    'debate',
#    'debate',
#    'molecula',
#    'president'],
#   'topics_weights': [('science', 0.4397688812367044),
#    ('politics', 0.5602311187632957)]},
#  {'id': 20,
#   'words': ['twitter',
#    'debate',
#    'twitter',
#    'space',
#    'twitter',
#    'molecula',
#    'president',
#    'president',
#    'debate',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'twitter',
#    'twitter',
#    'interview',
#    'molecula',
#    'debate',
#    'president',
#    'twitter',
#    'molecula',
#    'science',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'debate',
#    'science',
#    'molecula',
#    'twitter',
#    'space',
#    'space',
#    'twitter',
#    'twitter',
#    'debate',
#    'debate',
#    'debate',
#    'president',
#    'twitter',
#    'space',
#    'space',
#    'television',
#    'science',
#    'space',
#    'molecula',
#    'debate',
#    'science',
#    'television',
#    'president',
#    'debate',
#    'twitter',
#    'debate',
#    'debate',
#    'molecula',
#    'space',
#    'space',
#    'debate',
#    'interview',
#    'twitter',
#    'debate',
#    'twitter',
#    'science',
#    'television',
#    'space',
#    'debate',
#    'molecula',
#    'president',
#    'space',
#    'television',
#    'science',
#    'interview',
#    'debate',
#    'president',
#    'president',
#    'television',
#    'space',
#    'debate',
#    'molecula',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'television',
#    'debate',
#    'space',
#    'science',
#    'space',
#    'twitter',
#    'president',
#    'president',
#    'molecula'],
#   'topics_weights': [('science', 0.5143138390787939),
#    ('politics', 0.48568616092120614)]},
#  {'id': 21,
#   'words': ['football',
#    'space',
#    'space',
#    'play',
#    'play',
#    'football',
#    'space',
#    'science',
#    'molecula',
#    'basketball',
#    'molecula',
#    'space',
#    'basketball',
#    'space',
#    'debate',
#    'debate',
#    'science',
#    'molecula',
#    'match',
#    'molecula',
#    'molecula',
#    'science',
#    'space',
#    'science',
#    'football',
#    'science',
#    'football',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'basketball',
#    'debate',
#    'gol',
#    'molecula',
#    'space',
#    'science',
#    'play',
#    'basketball',
#    'space',
#    'play',
#    'science',
#    'molecula',
#    'molecula',
#    'play',
#    'molecula',
#    'space',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'basketball',
#    'debate',
#    'gol',
#    'space',
#    'football',
#    'space',
#    'space',
#    'match',
#    'football',
#    'debate',
#    'gol',
#    'space',
#    'space',
#    'match',
#    'space',
#    'match',
#    'football',
#    'science',
#    'play',
#    'play',
#    'molecula',
#    'football',
#    'football',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'science',
#    'space',
#    'molecula',
#    'science',
#    'football',
#    'debate',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'science',
#    'play',
#    'space',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'football'],
#   'topics_weights': [('sports', 0.4672941811111519),
#    ('science', 0.532705818888848)]},
#  {'id': 22,
#   'words': ['space',
#    'science',
#    'basketball',
#    'debate',
#    'molecula',
#    'space',
#    'molecula',
#    'space',
#    'gol',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'gol',
#    'molecula',
#    'space',
#    'gol',
#    'space',
#    'football',
#    'space',
#    'space',
#    'space',
#    'space',
#    'football',
#    'match',
#    'basketball',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'space',
#    'football',
#    'molecula',
#    'debate',
#    'space',
#    'match',
#    'basketball',
#    'football',
#    'basketball',
#    'basketball',
#    'match',
#    'play',
#    'space',
#    'debate',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'match',
#    'space',
#    'play',
#    'football',
#    'space',
#    'match',
#    'molecula',
#    'gol',
#    'football',
#    'molecula',
#    'basketball',
#    'football',
#    'football',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'play',
#    'science',
#    'molecula',
#    'space',
#    'space',
#    'football',
#    'basketball',
#    'basketball',
#    'gol',
#    'molecula',
#    'debate',
#    'molecula',
#    'football',
#    'football',
#    'space',
#    'space',
#    'space',
#    'basketball',
#    'space',
#    'space',
#    'football',
#    'football',
#    'space',
#    'football',
#    'debate',
#    'space',
#    'football',
#    'science',
#    'football'],
#   'topics_weights': [('sports', 0.6562838766968819),
#    ('science', 0.3437161233031181)]},
#  {'id': 23,
#   'words': ['space',
#    'space',
#    'match',
#    'football',
#    'match',
#    'football',
#    'space',
#    'match',
#    'football',
#    'football',
#    'play',
#    'gol',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'debate',
#    'football',
#    'play',
#    'basketball',
#    'football',
#    'space',
#    'space',
#    'play',
#    'gol',
#    'gol',
#    'football',
#    'basketball',
#    'gol',
#    'match',
#    'debate',
#    'space',
#    'gol',
#    'debate',
#    'match',
#    'football',
#    'football',
#    'basketball',
#    'basketball',
#    'play',
#    'molecula',
#    'football',
#    'space',
#    'match',
#    'football',
#    'football',
#    'space',
#    'football',
#    'molecula',
#    'space',
#    'play',
#    'play',
#    'space',
#    'football',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'football',
#    'space',
#    'football',
#    'space',
#    'space',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'football',
#    'debate',
#    'football',
#    'football',
#    'football',
#    'football',
#    'play',
#    'football',
#    'space',
#    'football',
#    'play',
#    'gol',
#    'match',
#    'debate',
#    'football',
#    'basketball',
#    'play',
#    'football',
#    'space',
#    'football',
#    'play',
#    'match',
#    'gol',
#    'gol',
#    'space',
#    'space'],
#   'topics_weights': [('sports', 0.8664036037523462),
#    ('science', 0.13359639624765388)]},
#  {'id': 24,
#   'words': ['science',
#    'gol',
#    'molecula',
#    'debate',
#    'basketball',
#    'football',
#    'debate',
#    'play',
#    'science',
#    'football',
#    'debate',
#    'space',
#    'space',
#    'football',
#    'molecula',
#    'gol',
#    'science',
#    'space',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'space',
#    'gol',
#    'science',
#    'gol',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'space',
#    'science',
#    'science',
#    'gol',
#    'basketball',
#    'space',
#    'molecula',
#    'football',
#    'space',
#    'debate',
#    'science',
#    'science',
#    'space',
#    'football',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'football',
#    'science',
#    'basketball',
#    'molecula',
#    'molecula',
#    'science',
#    'football',
#    'debate',
#    'debate',
#    'space',
#    'science',
#    'molecula',
#    'space',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'play',
#    'molecula',
#    'space',
#    'space',
#    'space',
#    'molecula',
#    'football',
#    'debate',
#    'space',
#    'space',
#    'science',
#    'basketball',
#    'football',
#    'molecula',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'space'],
#   'topics_weights': [('science', 0.6942934972171066),
#    ('sports', 0.30570650278289335)]},
#  {'id': 25,
#   'words': ['football',
#    'president',
#    'gol',
#    'gol',
#    'football',
#    'space',
#    'play',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'gol',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'basketball',
#    'gol',
#    'match',
#    'president',
#    'interview',
#    'space',
#    'twitter',
#    'president',
#    'interview',
#    'space',
#    'match',
#    'basketball',
#    'gol',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'television',
#    'gol',
#    'space',
#    'football',
#    'play',
#    'football',
#    'gol',
#    'president',
#    'basketball',
#    'match',
#    'twitter',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'match',
#    'basketball',
#    'president',
#    'space',
#    'gol',
#    'basketball',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'interview',
#    'space',
#    'space',
#    'football',
#    'basketball',
#    'match',
#    'space',
#    'basketball',
#    'basketball',
#    'twitter',
#    'football',
#    'space',
#    'space',
#    'gol',
#    'play',
#    'space',
#    'match',
#    'play',
#    'president',
#    'space',
#    'space',
#    'gol',
#    'play',
#    'twitter',
#    'television',
#    'football',
#    'space',
#    'debate',
#    'basketball',
#    'play',
#    'debate',
#    'gol',
#    'football',
#    'interview',
#    'interview',
#    'football',
#    'football',
#    'football'],
#   'topics_weights': [('sports', 0.7101977854153113),
#    ('politics', 0.28980221458468874)]},
#  {'id': 26,
#   'words': ['play',
#    'debate',
#    'space',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'space',
#    'debate',
#    'play',
#    'debate',
#    'science',
#    'molecula',
#    'space',
#    'football',
#    'football',
#    'debate',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'gol',
#    'science',
#    'science',
#    'football',
#    'science',
#    'debate',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'gol',
#    'football',
#    'molecula',
#    'science',
#    'science',
#    'football',
#    'debate',
#    'space',
#    'football',
#    'football',
#    'molecula',
#    'molecula',
#    'space',
#    'molecula',
#    'science',
#    'match',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'football',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'science',
#    'molecula',
#    'space',
#    'football',
#    'science',
#    'space',
#    'football',
#    'molecula',
#    'space',
#    'football',
#    'football',
#    'science',
#    'debate',
#    'science',
#    'molecula',
#    'debate',
#    'football',
#    'debate',
#    'science',
#    'football',
#    'space',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'football',
#    'molecula',
#    'molecula',
#    'debate',
#    'debate',
#    'debate',
#    'debate',
#    'molecula',
#    'football',
#    'space'],
#   'topics_weights': [('science', 0.7113156066986488),
#    ('sports', 0.2886843933013511)]},
#  {'id': 27,
#   'words': ['twitter',
#    'science',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'debate',
#    'science',
#    'twitter',
#    'science',
#    'twitter',
#    'molecula',
#    'science',
#    'space',
#    'science',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'space',
#    'debate',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'science',
#    'molecula',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'molecula',
#    'molecula',
#    'molecula',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'science',
#    'space',
#    'debate',
#    'science',
#    'molecula',
#    'molecula',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'molecula',
#    'debate',
#    'space',
#    'debate',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'debate',
#    'debate',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'space',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'space',
#    'space',
#    'molecula',
#    'television',
#    'science',
#    'science',
#    'science',
#    'science',
#    'science',
#    'debate',
#    'molecula',
#    'science',
#    'debate',
#    'science',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'science',
#    'space',
#    'molecula',
#    'science'],
#   'topics_weights': [('science', 0.8677584672048038),
#    ('politics', 0.13224153279519626)]},
#  {'id': 28,
#   'words': ['science',
#    'debate',
#    'twitter',
#    'twitter',
#    'debate',
#    'science',
#    'science',
#    'president',
#    'debate',
#    'space',
#    'molecula',
#    'president',
#    'molecula',
#    'twitter',
#    'science',
#    'debate',
#    'science',
#    'space',
#    'science',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'television',
#    'molecula',
#    'science',
#    'president',
#    'debate',
#    'science',
#    'space',
#    'molecula',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'space',
#    'molecula',
#    'molecula',
#    'debate',
#    'science',
#    'molecula',
#    'science',
#    'twitter',
#    'science',
#    'molecula',
#    'space',
#    'debate',
#    'television',
#    'space',
#    'space',
#    'twitter',
#    'debate',
#    'debate',
#    'president',
#    'debate',
#    'molecula',
#    'space',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'twitter',
#    'debate',
#    'space',
#    'science',
#    'twitter',
#    'science',
#    'space',
#    'debate',
#    'debate',
#    'debate',
#    'president',
#    'space',
#    'science',
#    'science',
#    'president',
#    'space',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'space',
#    'debate',
#    'science',
#    'science',
#    'space',
#    'debate',
#    'president',
#    'debate',
#    'space',
#    'science',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'space'],
#   'topics_weights': [('politics', 0.21769194798450933),
#    ('science', 0.7823080520154907)]},
#  {'id': 29,
#   'words': ['space',
#    'science',
#    'space',
#    'gol',
#    'science',
#    'molecula',
#    'football',
#    'space',
#    'play',
#    'match',
#    'debate',
#    'space',
#    'gol',
#    'space',
#    'science',
#    'football',
#    'space',
#    'basketball',
#    'molecula',
#    'football',
#    'science',
#    'football',
#    'play',
#    'debate',
#    'science',
#    'molecula',
#    'debate',
#    'gol',
#    'molecula',
#    'space',
#    'gol',
#    'basketball',
#    'debate',
#    'debate',
#    'debate',
#    'science',
#    'football',
#    'science',
#    'debate',
#    'football',
#    'debate',
#    'molecula',
#    'football',
#    'football',
#    'space',
#    'space',
#    'football',
#    'space',
#    'space',
#    'debate',
#    'space',
#    'match',
#    'science',
#    'debate',
#    'football',
#    'space',
#    'science',
#    'gol',
#    'football',
#    'science',
#    'space',
#    'space',
#    'match',
#    'molecula',
#    'space',
#    'molecula',
#    'molecula',
#    'molecula',
#    'football',
#    'gol',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'play',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'molecula',
#    'football',
#    'debate',
#    'football',
#    'debate',
#    'science',
#    'football',
#    'debate',
#    'science',
#    'football',
#    'debate',
#    'football',
#    'space',
#    'football',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'football',
#    'space',
#    'molecula'],
#   'topics_weights': [('science', 0.6026340575083013),
#    ('sports', 0.3973659424916986)]},
#  {'id': 30,
#   'words': ['gol',
#    'gol',
#    'basketball',
#    'twitter',
#    'president',
#    'match',
#    'gol',
#    'match',
#    'football',
#    'space',
#    'football',
#    'twitter',
#    'basketball',
#    'twitter',
#    'president',
#    'play',
#    'play',
#    'space',
#    'interview',
#    'gol',
#    'gol',
#    'space',
#    'space',
#    'twitter',
#    'match',
#    'television',
#    'twitter',
#    'football',
#    'interview',
#    'television',
#    'match',
#    'football',
#    'twitter',
#    'twitter',
#    'basketball',
#    'interview',
#    'president',
#    'football',
#    'match',
#    'football',
#    'twitter',
#    'interview',
#    'gol',
#    'football',
#    'football',
#    'basketball',
#    'television',
#    'space',
#    'play',
#    'gol',
#    'match',
#    'debate',
#    'gol',
#    'gol',
#    'play',
#    'debate',
#    'space',
#    'space',
#    'president',
#    'play',
#    'president',
#    'football',
#    'gol',
#    'gol',
#    'football',
#    'football',
#    'space',
#    'match',
#    'football',
#    'football',
#    'football',
#    'football',
#    'interview',
#    'space',
#    'television',
#    'twitter',
#    'president',
#    'football',
#    'play',
#    'football',
#    'space',
#    'president',
#    'space',
#    'president',
#    'football',
#    'space',
#    'play',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'play',
#    'twitter',
#    'football',
#    'twitter',
#    'gol',
#    'space'],
#   'topics_weights': [('politics', 0.38074113082862276),
#    ('sports', 0.6192588691713773)]},
#  {'id': 31,
#   'words': ['football',
#    'football',
#    'match',
#    'space',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'football',
#    'debate',
#    'space',
#    'gol',
#    'football',
#    'molecula',
#    'football',
#    'play',
#    'match',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'basketball',
#    'debate',
#    'space',
#    'space',
#    'football',
#    'gol',
#    'space',
#    'molecula',
#    'basketball',
#    'football',
#    'science',
#    'gol',
#    'space',
#    'molecula',
#    'basketball',
#    'gol',
#    'space',
#    'space',
#    'space',
#    'basketball',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'molecula',
#    'football',
#    'space',
#    'football',
#    'debate',
#    'science',
#    'space',
#    'match',
#    'space',
#    'molecula',
#    'space',
#    'match',
#    'gol',
#    'basketball',
#    'molecula',
#    'science',
#    'football',
#    'science',
#    'debate',
#    'molecula',
#    'debate',
#    'space',
#    'football',
#    'debate',
#    'molecula',
#    'basketball',
#    'space',
#    'football',
#    'molecula',
#    'football',
#    'space',
#    'football',
#    'molecula',
#    'play',
#    'space',
#    'debate',
#    'molecula',
#    'match',
#    'molecula',
#    'football',
#    'debate',
#    'football',
#    'basketball',
#    'debate',
#    'molecula',
#    'football',
#    'space',
#    'molecula',
#    'science',
#    'play',
#    'football',
#    'space',
#    'gol',
#    'play',
#    'molecula'],
#   'topics_weights': [('sports', 0.6073445395886145),
#    ('science', 0.3926554604113856)]},
#  {'id': 32,
#   'words': ['space',
#    'science',
#    'molecula',
#    'play',
#    'football',
#    'space',
#    'debate',
#    'play',
#    'space',
#    'debate',
#    'science',
#    'football',
#    'football',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'science',
#    'molecula',
#    'debate',
#    'molecula',
#    'football',
#    'molecula',
#    'science',
#    'molecula',
#    'science',
#    'science',
#    'space',
#    'space',
#    'debate',
#    'football',
#    'football',
#    'football',
#    'molecula',
#    'science',
#    'basketball',
# ...
#    'space',
#    'space',
#    'molecula',
#    'molecula',
#    'science',
#    'president',
#    'space',
#    'space',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'president',
#    'molecula',
#    'science',
#    'molecula',
#    'molecula',
#    'molecula',
#    'molecula',
#    'space',
#    'debate',
#    'molecula',
#    'science',
#    'molecula',
#    'twitter',
#    'debate',
#    'debate',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'space',
#    'twitter',
#    'science',
#    'molecula',
#    'molecula',
#    'debate',
#    'president',
#    'molecula',
#    'debate',
#    'science',
#    'twitter',
#    'science',
#    'debate',
#    'debate',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'molecula',
#    'science',
#    'science',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'molecula'],
#   'topics_weights': [('politics', 0.10605084045600463),
#    ('science', 0.8939491595439953)]},
#  {'id': 90,
#   'words': ['debate',
#    'space',
#    'space',
#    'molecula',
#    'debate',
#    'molecula',
#    'science',
#    'president',
#    'debate',
#    'twitter',
#    'science',
#    'twitter',
#    'debate',
#    'molecula',
#    'debate',
#    'science',
#    'president',
#    'science',
#    'space',
#    'president',
#    'debate',
#    'science',
#    'science',
#    'interview',
#    'debate',
#    'molecula',
#    'science',
#    'twitter',
#    'debate',
#    'science',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'molecula',
#    'president',
#    'debate',
#    'debate',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'molecula',
#    'television',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'debate',
#    'molecula',
#    'debate',
#    'twitter',
#    'interview',
#    'molecula',
#    'twitter',
#    'debate',
#    'space',
#    'science',
#    'science',
#    'molecula',
#    'molecula',
#    'television',
#    'science',
#    'molecula',
#    'molecula',
#    'space',
#    'space',
#    'science',
#    'debate',
#    'science',
#    'president',
#    'television',
#    'twitter',
#    'science',
#    'space',
#    'twitter',
#    'science',
#    'television',
#    'science',
#    'science',
#    'debate',
#    'space',
#    'debate',
#    'molecula',
#    'molecula',
#    'twitter',
#    'twitter',
#    'space',
#    'science',
#    'molecula',
#    'science',
#    'space',
#    'debate',
#    'space',
#    'space',
#    'debate',
#    'molecula',
#    'debate',
#    'space'],
#   'topics_weights': [('politics', 0.31971293675040124),
#    ('science', 0.6802870632495988)]},
#  {'id': 91,
#   'words': ['space',
#    'space',
#    'play',
#    'play',
#    'football',
#    'football',
#    'play',
#    'twitter',
#    'football',
#    'play',
#    'basketball',
#    'football',
#    'football',
#    'football',
#    'space',
#    'match',
#    'space',
#    'gol',
#    'gol',
#    'football',
#    'football',
#    'football',
#    'play',
#    'football',
#    'football',
#    'football',
#    'gol',
#    'football',
#    'play',
#    'match',
#    'space',
#    'match',
#    'football',
#    'basketball',
#    'football',
#    'play',
#    'football',
#    'football',
#    'space',
#    'gol',
#    'basketball',
#    'gol',
#    'match',
#    'football',
#    'basketball',
#    'space',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'play',
#    'basketball',
#    'match',
#    'football',
#    'play',
#    'space',
#    'football',
#    'space',
#    'space',
#    'football',
#    'football',
#    'football',
#    'space',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'basketball',
#    'football',
#    'gol',
#    'play',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'football',
#    'gol',
#    'space',
#    'football',
#    'match',
#    'basketball',
#    'match',
#    'basketball',
#    'football',
#    'play',
#    'president',
#    'space',
#    'football',
#    'football',
#    'football',
#    'space',
#    'match',
#    'space',
#    'football',
#    'football',
#    'gol'],
#   'topics_weights': [('sports', 0.9731373446545435),
#    ('politics', 0.02686265534545648)]},
#  {'id': 92,
#   'words': ['twitter',
#    'molecula',
#    'debate',
#    'space',
#    'space',
#    'twitter',
#    'television',
#    'molecula',
#    'debate',
#    'twitter',
#    'space',
#    'television',
#    'president',
#    'science',
#    'debate',
#    'space',
#    'science',
#    'molecula',
#    'molecula',
#    'space',
#    'president',
#    'president',
#    'molecula',
#    'molecula',
#    'science',
#    'debate',
#    'television',
#    'space',
#    'twitter',
#    'molecula',
#    'debate',
#    'twitter',
#    'interview',
#    'interview',
#    'twitter',
#    'interview',
#    'twitter',
#    'molecula',
#    'space',
#    'debate',
#    'debate',
#    'space',
#    'twitter',
#    'molecula',
#    'president',
#    'twitter',
#    'debate',
#    'science',
#    'debate',
#    'space',
#    'space',
#    'space',
#    'interview',
#    'debate',
#    'space',
#    'television',
#    'science',
#    'space',
#    'debate',
#    'president',
#    'twitter',
#    'science',
#    'molecula',
#    'television',
#    'molecula',
#    'science',
#    'president',
#    'science',
#    'television',
#    'twitter',
#    'debate',
#    'debate',
#    'molecula',
#    'space',
#    'debate',
#    'interview',
#    'molecula',
#    'debate',
#    'space',
#    'science',
#    'space',
#    'molecula',
#    'interview',
#    'space',
#    'debate',
#    'molecula',
#    'twitter',
#    'twitter',
#    'molecula',
#    'interview',
#    'debate',
#    'debate',
#    'debate',
#    'debate',
#    'debate',
#    'science',
#    'science',
#    'twitter',
#    'president',
#    'molecula'],
#   'topics_weights': [('science', 0.4380061848562769),
#    ('politics', 0.5619938151437232)]},
#  {'id': 93,
#   'words': ['space',
#    'football',
#    'space',
#    'debate',
#    'match',
#    'space',
#    'match',
#    'gol',
#    'science',
#    'space',
#    'football',
#    'debate',
#    'football',
#    'debate',
#    'space',
#    'space',
#    'gol',
#    'space',
#    'football',
#    'football',
#    'play',
#    'match',
#    'play',
#    'play',
#    'space',
#    'space',
#    'football',
#    'football',
#    'play',
#    'space',
#    'space',
#    'science',
#    'basketball',
#    'match',
#    'match',
#    'debate',
#    'space',
#    'football',
#    'play',
#    'play',
#    'space',
#    'space',
#    'space',
#    'basketball',
#    'molecula',
#    'football',
#    'space',
#    'play',
#    'play',
#    'football',
#    'match',
#    'space',
#    'space',
#    'space',
#    'basketball',
#    'football',
#    'debate',
#    'football',
#    'debate',
#    'football',
#    'match',
#    'gol',
#    'play',
#    'gol',
#    'basketball',
#    'football',
#    'football',
#    'gol',
#    'space',
#    'science',
#    'play',
#    'space',
#    'match',
#    'molecula',
#    'football',
#    'science',
#    'space',
#    'basketball',
#    'space',
#    'football',
#    'molecula',
#    'space',
#    'gol',
#    'play',
#    'play',
#    'molecula',
#    'gol',
#    'football',
#    'debate',
#    'space',
#    'space',
#    'space',
#    'space',
#    'football',
#    'space',
#    'basketball',
#    'play',
#    'basketball',
#    'molecula',
#    'match'],
#   'topics_weights': [('science', 0.25968270180936853),
#    ('sports', 0.7403172981906314)]},
#  {'id': 94,
#   'words': ['twitter',
#    'interview',
#    'debate',
#    'match',
#    'play',
#    'space',
#    'twitter',
#    'twitter',
#    'football',
#    'twitter',
#    'football',
#    'president',
#    'football',
#    'football',
#    'twitter',
#    'space',
#    'space',
#    'space',
#    'match',
#    'football',
#    'twitter',
#    'space',
#    'space',
#    'football',
#    'television',
#    'football',
#    'space',
#    'president',
#    'basketball',
#    'football',
#    'football',
#    'space',
#    'football',
#    'football',
#    'space',
#    'twitter',
#    'interview',
#    'debate',
#    'play',
#    'football',
#    'gol',
#    'play',
#    'football',
#    'president',
#    'football',
#    'interview',
#    'twitter',
#    'space',
#    'gol',
#    'space',
#    'space',
#    'twitter',
#    'space',
#    'play',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'match',
#    'play',
#    'basketball',
#    'president',
#    'football',
#    'space',
#    'president',
#    'debate',
#    'twitter',
#    'interview',
#    'twitter',
#    'football',
#    'twitter',
#    'football',
#    'interview',
#    'play',
#    'television',
#    'president',
#    'football',
#    'basketball',
#    'television',
#    'football',
#    'football',
#    'football',
#    'play',
#    'twitter',
#    'twitter',
#    'football',
#    'play',
#    'interview',
#    'space',
#    'football',
#    'football',
#    'play',
#    'twitter',
#    'twitter',
#    'space',
#    'space',
#    'football',
#    'football',
#    'space',
#    'president'],
#   'topics_weights': [('sports', 0.5219504617082176),
#    ('politics', 0.4780495382917825)]},
#  {'id': 95,
#   'words': ['twitter',
#    'twitter',
#    'gol',
#    'space',
#    'president',
#    'space',
#    'space',
#    'twitter',
#    'basketball',
#    'twitter',
#    'twitter',
#    'football',
#    'football',
#    'twitter',
#    'twitter',
#    'debate',
#    'television',
#    'president',
#    'president',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'interview',
#    'football',
#    'basketball',
#    'football',
#    'football',
#    'space',
#    'twitter',
#    'space',
#    'match',
#    'twitter',
#    'twitter',
#    'television',
#    'football',
#    'president',
#    'space',
#    'interview',
#    'president',
#    'twitter',
#    'president',
#    'basketball',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'interview',
#    'space',
#    'president',
#    'space',
#    'twitter',
#    'football',
#    'twitter',
#    'president',
#    'television',
#    'twitter',
#    'space',
#    'space',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'interview',
#    'twitter',
#    'president',
#    'twitter',
#    'gol',
#    'twitter',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'space',
#    'president',
#    'twitter',
#    'match',
#    'twitter',
#    'twitter',
#    'television',
#    'twitter',
#    'debate',
#    'twitter',
#    'football',
#    'television',
#    'president',
#    'space',
#    'twitter',
#    'twitter',
#    'space'],
#   'topics_weights': [('sports', 0.1683915791061135),
#    ('politics', 0.8316084208938866)]},
#  {'id': 96,
#   'words': ['television',
#    'football',
#    'football',
#    'football',
#    'twitter',
#    'play',
#    'twitter',
#    'play',
#    'debate',
#    'football',
#    'space',
#    'play',
#    'play',
#    'twitter',
#    'president',
#    'debate',
#    'space',
#    'play',
#    'football',
#    'debate',
#    'football',
#    'basketball',
#    'twitter',
#    'twitter',
#    'basketball',
#    'play',
#    'football',
#    'football',
#    'football',
#    'gol',
#    'twitter',
#    'debate',
#    'football',
#    'football',
#    'match',
#    'twitter',
#    'space',
#    'interview',
#    'football',
#    'president',
#    'football',
#    'television',
#    'space',
#    'football',
#    'twitter',
#    'president',
#    'football',
#    'football',
#    'president',
#    'twitter',
#    'match',
#    'gol',
#    'space',
#    'play',
#    'space',
#    'space',
#    'television',
#    'basketball',
#    'football',
#    'interview',
#    'football',
#    'play',
#    'twitter',
#    'football',
#    'match',
#    'match',
#    'gol',
#    'gol',
#    'debate',
#    'president',
#    'twitter',
#    'president',
#    'gol',
#    'interview',
#    'football',
#    'play',
#    'basketball',
#    'play',
#    'debate',
#    'football',
#    'football',
#    'president',
#    'space',
#    'space',
#    'television',
#    'play',
#    'twitter',
#    'interview',
#    'basketball',
#    'space',
#    'interview',
#    'twitter',
#    'play',
#    'basketball',
#    'football',
#    'twitter',
#    'president',
#    'interview',
#    'football',
#    'debate'],
#   'topics_weights': [('sports', 0.5382945071050944),
#    ('politics', 0.4617054928949055)]},
#  {'id': 97,
#   'words': ['debate',
#    'space',
#    'twitter',
#    'television',
#    'president',
#    'twitter',
#    'twitter',
#    'debate',
#    'space',
#    'molecula',
#    'science',
#    'space',
#    'science',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'interview',
#    'space',
#    'science',
#    'interview',
#    'twitter',
#    'twitter',
#    'space',
#    'twitter',
#    'science',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'molecula',
#    'television',
#    'molecula',
#    'president',
#    'debate',
#    'molecula',
#    'interview',
#    'debate',
#    'twitter',
#    'debate',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'debate',
#    'molecula',
#    'twitter',
#    'television',
#    'science',
#    'president',
#    'debate',
#    'twitter',
#    'twitter',
#    'twitter',
#    'interview',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'debate',
#    'president',
#    'twitter',
#    'interview',
#    'interview',
#    'twitter',
#    'twitter',
#    'president',
#    'president',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'twitter',
#    'space',
#    'television',
#    'twitter',
#    'twitter',
#    'space',
#    'debate',
#    'twitter',
#    'interview',
#    'debate',
#    'twitter',
#    'twitter',
#    'twitter',
#    'molecula',
#    'space',
#    'television',
#    'twitter',
#    'television',
#    'president',
#    'science',
#    'television',
#    'debate',
#    'interview',
#    'television',
#    'twitter'],
#   'topics_weights': [('politics', 0.8283366002458811),
#    ('science', 0.1716633997541189)]},
#  {'id': 98,
#   'words': ['basketball',
#    'president',
#    'match',
#    'twitter',
#    'twitter',
#    'television',
#    'space',
#    'president',
#    'gol',
#    'twitter',
#    'space',
#    'gol',
#    'space',
#    'football',
#    'twitter',
#    'space',
#    'gol',
#    'football',
#    'space',
#    'twitter',
#    'space',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'play',
#    'twitter',
#    'television',
#    'twitter',
#    'football',
#    'football',
#    'match',
#    'debate',
#    'twitter',
#    'president',
#    'debate',
#    'football',
#    'space',
#    'twitter',
#    'space',
#    'play',
#    'football',
#    'match',
#    'football',
#    'interview',
#    'space',
#    'twitter',
#    'play',
#    'twitter',
#    'interview',
#    'television',
#    'twitter',
#    'football',
#    'debate',
#    'football',
#    'space',
#    'president',
#    'president',
#    'football',
#    'football',
#    'president',
#    'space',
#    'twitter',
#    'match',
#    'space',
#    'president',
#    'president',
#    'football',
#    'football',
#    'twitter',
#    'space',
#    'interview',
#    'president',
#    'twitter',
#    'football',
#    'interview',
#    'space',
#    'television',
#    'gol',
#    'play',
#    'play',
#    'basketball',
#    'president',
#    'space',
#    'president',
#    'television',
#    'football',
#    'twitter',
#    'space',
#    'football',
#    'president',
#    'football',
#    'president',
#    'space',
#    'football',
#    'football',
#    'president',
#    'gol',
#    'twitter',
#    'match'],
#   'topics_weights': [('sports', 0.5750825524210346),
#    ('politics', 0.42491744757896555)]},
#  {'id': 99,
#   'words': ['twitter',
#    'television',
#    'twitter',
#    'president',
#    'interview',
#    'debate',
#    'president',
#    'twitter',
#    'debate',
#    'twitter',
#    'president',
#    'twitter',
#    'president',
#    'president',
#    'debate',
#    'twitter',
#    'president',
#    'television',
#    'twitter',
#    'twitter',
#    'twitter',
#    'debate',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'debate',
#    'television',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'twitter',
#    'television',
#    'interview',
#    'twitter',
#    'twitter',
#    'president',
#    'twitter',
#    'twitter',
#    'interview',
#    'television',
#    'twitter',
#    'twitter',
#    'debate',
#    'twitter',
#    'space',
#    'space',
#    'twitter',
#    'president',
#    'interview',
#    'debate',
#    'president',
#    'space',
#    'twitter',
#    'space',
#    'interview',
#    'president',
#    'interview',
#    'president',
#    'twitter',
#    'debate',
#    'space',
#    'twitter',
#    'twitter',
#    'president',
#    'interview',
#    'president',
#    'twitter',
#    'twitter',
#    'twitter',
#    'president',
#    'space',
#    'interview',
#    'twitter',
#    'president',
#    'interview',
#    'space',
#    'debate',
#    'twitter',
#    'debate',
#    'twitter',
#    'president',
#    'twitter',
#    'television',
#    'twitter',
#    'twitter',
#    'debate',
#    'president',
#    'president',
#    'television',
#    'television',
#    'president',
#    'space',
#    'television',
#    'president',
#    'debate',
#    'debate',
#    'twitter',
#    'television'],
#   'topics_weights': [('politics', 0.9909240188039051),
#    ('science', 0.009075981196094821)]}]

# %%
def words_vs_topics_matrix(docs, words_idx, ntopics):
    m = np.zeros((len(words_idx), ntopics))
    for doc in docs:
        for a in doc['assignment']:
            word_j = words_idx.index(a['word'])
            m[word_j, a['topic']] += 1
    return m


def docs_vs_topics_matrix(docs, ntopics):
    m = np.zeros((len(docs), ntopics))
    for doc in docs:
        doc_i = docs.index(doc)
        for a in doc['assignment']:
            m[doc_i, a['topic']] += 1
    return m

test_docs = [
    {'id': 0, 'assignment': [{'word': 'A', 'topic': 0}, {'word': 'AA', 'topic': 0}]},
    {'id': 1, 'assignment': [{'word': 'B', 'topic': 1}, {'word': 'BB', 'topic': 1}]},
]

# TEST
words_vs_topics_matrix(test_docs, words_idx=['A', 'AA', 'B', 'BB'], ntopics=2) == np.array([[1,0],[1,0],[0,1],[0,1]])
# Out:
# array([[ True,  True],
#        [ True,  True],
#        [ True,  True],
#        [ True,  True]])

# %%
def prob_w_belongs_t_in_d(words_vs_topics, docs_vs_topics, d, w, t, old_topic, alpha, beta, debug=False):
    # P(w belongs topic) = P(word w | topic t) * P(topic t | doc d)
    # P(w belongs topic) = Proporcion(word w en el topic t) * Proporcion(topic t en el doc d)
    # prob_w_belongs_t = words_vs_topics[w, t]/words_vs_topics[:, t] * docs_vs_topics[d, t]/sum(docs_vs_topic[d, :])
    nwords, ntopics = words_vs_topics.shape
    ndocs, _ = docs_vs_topics.shape
    
    if debug:
        print("words_vs_topics=\n", words_vs_topics, words_vs_topics[w, t], (w,t))
        print("docs_vs_topics=\n", docs_vs_topics, docs_vs_topics[d, t], (d,t))
        print("t=", t)
        print("d=", d)
        print("w=", w)
        print("old_topic=", old_topic)
    
    if old_topic == t:
        # Note: as we are calculating the new topic assignation for w, we need to eliminate the
        # old assignation. That is why we rest -1 in those calculations
        assert words_vs_topics[w, t] > 0
        assert docs_vs_topics[d, t] > 0
        if debug:
            print("REMOVING OLD ASIGNATION")
            print((words_vs_topics[w, t]-1 + beta)/(sum(words_vs_topics[:, t])-1 + beta*nwords))
            print((docs_vs_topics[d, t]-1 + alpha)/(sum(docs_vs_topics[d, :])-1 + alpha*ntopics))
            input()
        return (words_vs_topics[w, t]-1 + beta)/(sum(words_vs_topics[:, t])-1 + beta*nwords) \
               * (docs_vs_topics[d, t]-1 + alpha)/(sum(docs_vs_topics[d, :])-1 + alpha*ntopics)
    else:
        if debug:
            print((words_vs_topics[w, t] + beta)/(sum(words_vs_topics[:, t]) + beta))
            print((docs_vs_topics[d, t] + alpha)/(sum(docs_vs_topics[d, :]) + alpha*ntopics))
            input()
        return (words_vs_topics[w, t] + beta)/(sum(words_vs_topics[:, t]) + beta) \
               * (docs_vs_topics[d, t] + alpha)/(sum(docs_vs_topics[d, :]) + alpha*ntopics)


def dirichlet_allocation(docs, docs_idx, words_idx, ntopics, niter=400, alpha=0.5, beta=0.01, debug=False):
    ndocs, nwords = len(docs_idx), len(words_idx)

    for doc in docs:
        assignment = zip(doc['words'], np.random.randint(0, ntopics, len(doc['words'])))  # get random initial assignment for each word in each document
        doc['assignment'] = [{'word': t[0], 'topic': t[1]} for t in assignment]
    
    for _ in range(niter):

        words_vs_topics = words_vs_topics_matrix(docs, words_idx, ntopics)
        # print(words_vs_topics)

        docs_vs_topics = docs_vs_topics_matrix(docs, ntopics)
        # print(docs_vs_topics)

        for doc in docs:
            doc_i = docs_idx.index(doc['id'])
            for assign in doc['assignment']:
                word = assign['word']
                word_j = words_idx.index(word)
                old_topic = assign['topic']
                prob_by_topic = [0] * ntopics  # unnormalized
                for topic_k in range(ntopics):
                    if debug:
                        print(f"==>> doc {doc_i}, word {word_j}, calculating for topic {topic_k} (old topic was {old_topic})")
                    p = prob_w_belongs_t_in_d(words_vs_topics, docs_vs_topics, doc_i, word_j, topic_k, old_topic=old_topic, alpha=alpha, beta=beta, debug=debug)
                    prob_by_topic[topic_k] = p

                new_topic = random.choices(range(ntopics), prob_by_topic, k=1)[0]
                assign['topic'] = new_topic

    return docs


docs = dirichlet_allocation(docs, docs_idx, words_idx, ntopics=3, niter=100)
# docs

# %%
def normalize_counter(c):
    total = sum(c.values(), 0.0)
    for key in c:
        c[key] /= total
    return c

for (i, d) in enumerate(docs):
    print(i, d['topics_weights'])
    topic_list = Counter([a['topic'] for a in d['assignment']])
    a = normalize_counter(Counter(topic_list))
    print(i, sorted(a.items()))
# Out:
# 0 [('science', 0.24456755248379008), ('sports', 0.75543244751621)]
# 0 [(0, 0.01), (1, 0.77), (2, 0.22)]
# 1 [('sports', 0.35727722282000307), ('politics', 0.6427227771799969)]
# 1 [(0, 0.62), (1, 0.37), (2, 0.01)]
# 2 [('sports', 0.542989916612604), ('science', 0.45701008338739607)]
# 2 [(1, 0.56), (2, 0.44)]
# 3 [('science', 0.39538758109917665), ('sports', 0.6046124189008233)]
# 3 [(1, 0.67), (2, 0.33)]
# 4 [('science', 0.07236994958194534), ('sports', 0.9276300504180547)]
# 4 [(0, 0.01), (1, 0.92), (2, 0.07)]
# 5 [('sports', 0.43887033509303514), ('politics', 0.5611296649069649)]
# 5 [(0, 0.58), (1, 0.42)]
# 6 [('sports', 0.11407328212216619), ('politics', 0.8859267178778338)]
# 6 [(0, 0.92), (1, 0.08)]
# 7 [('science', 0.6406622574014711), ('sports', 0.3593377425985289)]
# 7 [(1, 0.35), (2, 0.65)]
# 8 [('science', 0.09343523903964185), ('sports', 0.9065647609603581)]
# 8 [(1, 0.93), (2, 0.07)]
# 9 [('sports', 0.4143566061847329), ('science', 0.5856433938152672)]
# 9 [(1, 0.42), (2, 0.58)]
# 10 [('science', 0.5936265713383261), ('politics', 0.40637342866167403)]
# 10 [(0, 0.4), (2, 0.6)]
# 11 [('politics', 0.5305417543340212), ('sports', 0.46945824566597877)]
# 11 [(0, 0.5), (1, 0.5)]
# 12 [('sports', 0.415927780693171), ('science', 0.584072219306829)]
# 12 [(1, 0.43), (2, 0.57)]
# 13 [('science', 0.6011752452866223), ('politics', 0.3988247547133778)]
# 13 [(0, 0.5), (2, 0.5)]
# 14 [('sports', 0.6017576169801229), ('politics', 0.39824238301987713)]
# 14 [(0, 0.47), (1, 0.53)]
# 15 [('sports', 0.8546393923286264), ('science', 0.1453606076713736)]
# 15 [(1, 0.79), (2, 0.21)]
# 16 [('science', 0.5514140698624164), ('sports', 0.4485859301375837)]
# 16 [(1, 0.44), (2, 0.56)]
# 17 [('sports', 0.5966290926432847), ('politics', 0.40337090735671544)]
# 17 [(0, 0.38), (1, 0.62)]
# 18 [('science', 0.6074891321791508), ('politics', 0.3925108678208492)]
# 18 [(0, 0.39), (2, 0.61)]
# 19 [('science', 0.4397688812367044), ('politics', 0.5602311187632957)]
# 19 [(0, 0.54), (2, 0.46)]
# 20 [('science', 0.5143138390787939), ('politics', 0.48568616092120614)]
# 20 [(0, 0.52), (1, 0.01), (2, 0.47)]
# 21 [('sports', 0.4672941811111519), ('science', 0.532705818888848)]
# 21 [(1, 0.4), (2, 0.6)]
# 22 [('sports', 0.6562838766968819), ('science', 0.3437161233031181)]
# 22 [(1, 0.68), (2, 0.32)]
# 23 [('sports', 0.8664036037523462), ('science', 0.13359639624765388)]
# 23 [(1, 0.93), (2, 0.07)]
# 24 [('science', 0.6942934972171066), ('sports', 0.30570650278289335)]
# 24 [(1, 0.3), (2, 0.7)]
# 25 [('sports', 0.7101977854153113), ('politics', 0.28980221458468874)]
# 25 [(0, 0.25), (1, 0.75)]
# 26 [('science', 0.7113156066986488), ('sports', 0.2886843933013511)]
# 26 [(1, 0.25), (2, 0.75)]
# 27 [('science', 0.8677584672048038), ('politics', 0.13224153279519626)]
# 27 [(0, 0.06), (1, 0.01), (2, 0.93)]
# 28 [('politics', 0.21769194798450933), ('science', 0.7823080520154907)]
# 28 [(0, 0.24), (2, 0.76)]
# 29 [('science', 0.6026340575083013), ('sports', 0.3973659424916986)]
# 29 [(0, 0.01), (1, 0.43), (2, 0.56)]
# 30 [('politics', 0.38074113082862276), ('sports', 0.6192588691713773)]
# 30 [(0, 0.34), (1, 0.65), (2, 0.01)]
# 31 [('sports', 0.6073445395886145), ('science', 0.3926554604113856)]
# 31 [(1, 0.54), (2, 0.46)]
# 32 [('science', 0.6849642249628335), ('sports', 0.3150357750371665)]
# 32 [(1, 0.3), (2, 0.7)]
# 33 [('politics', 0.21469340080810173), ('science', 0.7853065991918983)]
# 33 [(0, 0.23), (2, 0.77)]
# 34 [('sports', 0.9271496199440428), ('science', 0.07285038005595727)]
# 34 [(1, 0.87), (2, 0.13)]
# 35 [('politics', 0.48720166170377543), ('science', 0.5127983382962246)]
# 35 [(0, 0.44), (2, 0.56)]
# 36 [('politics', 0.2395931747025802), ('science', 0.7604068252974198)]
# 36 [(0, 0.22), (2, 0.78)]
# 37 [('politics', 0.661487665921507), ('science', 0.33851233407849296)]
# 37 [(0, 0.62), (2, 0.38)]
# 38 [('politics', 0.04873360714546357), ('sports', 0.9512663928545364)]
# 38 [(0, 0.04), (1, 0.95), (2, 0.01)]
# 39 [('sports', 0.6467751006370329), ('science', 0.353224899362967)]
# 39 [(1, 0.73), (2, 0.27)]
# 40 [('science', 0.5234115415742353), ('politics', 0.47658845842576475)]
# 40 [(0, 0.45), (2, 0.55)]
# 41 [('sports', 0.5667582248714024), ('politics', 0.4332417751285975)]
# 41 [(0, 0.41), (1, 0.59)]
# 42 [('sports', 0.31054793565491806), ('science', 0.6894520643450819)]
# 42 [(1, 0.41), (2, 0.59)]
# 43 [('politics', 0.41488801200791653), ('sports', 0.5851119879920835)]
# 43 [(0, 0.31), (1, 0.69)]
# 44 [('science', 0.10736481024090286), ('sports', 0.8926351897590972)]
# 44 [(1, 0.95), (2, 0.05)]
# 45 [('science', 0.5862304393618908), ('sports', 0.4137695606381092)]
# 45 [(0, 0.01), (1, 0.33), (2, 0.66)]
# 46 [('sports', 0.7854839339939971), ('science', 0.21451606600600298)]
# 46 [(1, 0.84), (2, 0.16)]
# 47 [('politics', 0.04291130306186831), ('science', 0.9570886969381317)]
# 47 [(0, 0.05), (2, 0.95)]
# 48 [('sports', 0.4930279149809849), ('politics', 0.5069720850190151)]
# 48 [(0, 0.5), (1, 0.5)]
# 49 [('politics', 0.047472453582390696), ('science', 0.9525275464176093)]
# 49 [(0, 0.08), (2, 0.92)]
# 50 [('sports', 0.5945294672825318), ('science', 0.4054705327174683)]
# 50 [(1, 0.69), (2, 0.31)]
# 51 [('science', 0.5163734052552731), ('politics', 0.4836265947447269)]
# 51 [(0, 0.56), (2, 0.44)]
# 52 [('science', 0.4088268397730415), ('sports', 0.5911731602269584)]
# 52 [(1, 0.64), (2, 0.36)]
# 53 [('sports', 0.4780641398686021), ('politics', 0.5219358601313979)]
# 53 [(0, 0.51), (1, 0.49)]
# 54 [('science', 0.9925225508345576), ('sports', 0.007477449165442351)]
# 54 [(2, 1.0)]
# 55 [('politics', 0.5067738041464146), ('sports', 0.4932261958535854)]
# 55 [(0, 0.6), (1, 0.37), (2, 0.03)]
# 56 [('politics', 0.3772280623994024), ('science', 0.6227719376005976)]
# 56 [(0, 0.31), (2, 0.69)]
# 57 [('sports', 0.3833037089666032), ('politics', 0.6166962910333968)]
# 57 [(0, 0.61), (1, 0.38), (2, 0.01)]
# 58 [('sports', 0.16290487224281597), ('science', 0.8370951277571841)]
# 58 [(1, 0.11), (2, 0.89)]
# 59 [('sports', 0.8913806251404192), ('science', 0.10861937485958084)]
# 59 [(1, 0.92), (2, 0.08)]
# 60 [('science', 0.5793149654406872), ('sports', 0.42068503455931283)]
# 60 [(1, 0.5), (2, 0.5)]
# 61 [('science', 0.44018345970880807), ('politics', 0.5598165402911919)]
# 61 [(0, 0.58), (2, 0.42)]
# 62 [('politics', 0.4993944703482724), ('science', 0.5006055296517277)]
# 62 [(0, 0.55), (2, 0.45)]
# 63 [('sports', 0.3130061162333241), ('politics', 0.6869938837666759)]
# 63 [(0, 0.65), (1, 0.34), (2, 0.01)]
# 64 [('sports', 0.6586609092129182), ('science', 0.34133909078708186)]
# 64 [(1, 0.61), (2, 0.39)]
# 65 [('politics', 0.5232551160560007), ('science', 0.4767448839439992)]
# 65 [(0, 0.51), (2, 0.49)]
# 66 [('sports', 0.06310077966868345), ('science', 0.9368992203313166)]
# 66 [(1, 0.06), (2, 0.94)]
# 67 [('politics', 0.8528595852800448), ('sports', 0.1471404147199552)]
# 67 [(0, 0.89), (1, 0.1), (2, 0.01)]
# 68 [('science', 0.6238773059715202), ('politics', 0.37612269402847975)]
# 68 [(0, 0.51), (2, 0.49)]
# 69 [('politics', 0.8738002652112172), ('science', 0.12619973478878277)]
# 69 [(0, 0.88), (1, 0.01), (2, 0.11)]
# 70 [('sports', 0.66929895941906), ('politics', 0.3307010405809399)]
# 70 [(0, 0.33), (1, 0.67)]
# 71 [('sports', 0.4812088220119836), ('politics', 0.5187911779880164)]
# 71 [(0, 0.5), (1, 0.5)]
# 72 [('science', 0.41840019269754103), ('sports', 0.581599807302459)]
# 72 [(1, 0.58), (2, 0.42)]
# 73 [('science', 0.34686392748248746), ('sports', 0.6531360725175125)]
# 73 [(1, 0.55), (2, 0.45)]
# 74 [('sports', 0.18220008598697995), ('politics', 0.81779991401302)]
# 74 [(0, 0.83), (1, 0.17)]
# 75 [('politics', 0.9638557367153974), ('sports', 0.03614426328460261)]
# 75 [(0, 0.98), (1, 0.02)]
# 76 [('sports', 0.49927146434553193), ('politics', 0.5007285356544681)]
# 76 [(0, 0.43), (1, 0.57)]
# 77 [('politics', 0.3416459475508368), ('sports', 0.6583540524491631)]
# 77 [(0, 0.31), (1, 0.69)]
# 78 [('politics', 0.3634760626190225), ('sports', 0.6365239373809776)]
# 78 [(0, 0.32), (1, 0.68)]
# 79 [('sports', 0.2669655322794313), ('science', 0.7330344677205688)]
# 79 [(1, 0.33), (2, 0.67)]
# 80 [('science', 0.4533985801449402), ('politics', 0.5466014198550597)]
# 80 [(0, 0.48), (1, 0.01), (2, 0.51)]
# 81 [('politics', 0.3872920857994844), ('science', 0.6127079142005156)]
# 81 [(0, 0.36), (2, 0.64)]
# 82 [('science', 0.5439591751113056), ('sports', 0.45604082488869446)]
# 82 [(0, 0.01), (1, 0.4), (2, 0.59)]
# 83 [('sports', 0.8942442360359532), ('politics', 0.10575576396404686)]
# 83 [(0, 0.1), (1, 0.89), (2, 0.01)]
# 84 [('politics', 0.7192449022825467), ('sports', 0.28075509771745333)]
# 84 [(0, 0.76), (1, 0.24)]
# 85 [('sports', 0.4446394199428433), ('science', 0.5553605800571568)]
# 85 [(0, 0.01), (1, 0.5), (2, 0.49)]
# 86 [('sports', 0.8435603193760458), ('politics', 0.15643968062395422)]
# 86 [(0, 0.12), (1, 0.88)]
# 87 [('sports', 0.6138381362132139), ('politics', 0.3861618637867861)]
# 87 [(0, 0.37), (1, 0.62), (2, 0.01)]
# 88 [('sports', 0.37835033341268043), ('politics', 0.6216496665873196)]
# 88 [(0, 0.62), (1, 0.37), (2, 0.01)]
# 89 [('politics', 0.10605084045600463), ('science', 0.8939491595439953)]
# 89 [(0, 0.13), (1, 0.01), (2, 0.86)]
# 90 [('politics', 0.31971293675040124), ('science', 0.6802870632495988)]
# 90 [(0, 0.27), (2, 0.73)]
# 91 [('sports', 0.9731373446545435), ('politics', 0.02686265534545648)]
# 91 [(0, 0.02), (1, 0.98)]
# 92 [('science', 0.4380061848562769), ('politics', 0.5619938151437232)]
# 92 [(0, 0.43), (2, 0.57)]
# 93 [('science', 0.25968270180936853), ('sports', 0.7403172981906314)]
# 93 [(0, 0.01), (1, 0.77), (2, 0.22)]
# 94 [('sports', 0.5219504617082176), ('politics', 0.4780495382917825)]
# 94 [(0, 0.44), (1, 0.56)]
# 95 [('sports', 0.1683915791061135), ('politics', 0.8316084208938866)]
# 95 [(0, 0.8), (1, 0.19), (2, 0.01)]
# 96 [('sports', 0.5382945071050944), ('politics', 0.4617054928949055)]
# 96 [(0, 0.4), (1, 0.6)]
# 97 [('politics', 0.8283366002458811), ('science', 0.1716633997541189)]
# 97 [(0, 0.82), (2, 0.18)]
# 98 [('sports', 0.5750825524210346), ('politics', 0.42491744757896555)]
# 98 [(0, 0.5), (1, 0.5)]
# 99 [('politics', 0.9909240188039051), ('science', 0.009075981196094821)]
# 99 [(0, 0.99), (2, 0.01)]

# %% [markdown]
# ## TODO: this works but needs a speed up
